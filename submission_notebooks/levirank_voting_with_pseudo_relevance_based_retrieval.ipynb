# %%
# TASK 1: Creating retrieval document for the LeviRank system.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cleaning sample_data directory.
# !rm -r sample_data

# %%
# The list of files that are present in the pwd.
# !ls drive/MyDrive/touche-2022-prototyping/topics-task2-2022
# Out:
# backup-duoT5-voting-reranked.csv	 OBJECT1_OBJECT2-CLASSIFIER
# duoT5-voting-reranked.csv		 retrieval-1500.jsonl
# first_model_classifier-epoch-17-f1-5888  retrieval-2000.jsonl
# initial-retrieval-1500.csv		 topics-task2.csv
# initial-retrieval-2000.csv		 topics-task2.xml
# monoT5-input-1500.csv			 Touche
# monoT5-input-2000.csv			 touche_topics_query_expansion.csv
# monoT5-voting-reranked.csv

# %%
# Import statements, must required for the final script.
import logging
import tarfile
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
import spacy
import string
from tqdm import tqdm
from spacy.lang.en.stop_words import STOP_WORDS
import random
import numpy as np
import pandas as pd
random.seed(10)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# Spacy related import statements.
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
sp = spacy.load("en_core_web_sm")
all_stopwords = sp.Defaults.stop_words

# %%
# Sample test for checking out the spacy working.
text = sp("Nick likes to play football, however he is not too fond of tennis.")
# text_tokens = word_tokenize(text)
# print(text
#       )
token_list = []
token_tag_list = []
for token in text:
    token_list.append(token.text)
    token_tag_list.append(token.tag_)
print(token_list)
print(token_tag_list)
# Out:
# ['Nick', 'likes', 'to', 'play', 'football', ',', 'however', 'he', 'is', 'not', 'too', 'fond', 'of', 'tennis', '.']
# ['NNP', 'VBZ', 'TO', 'VB', 'NN', ',', 'RB', 'PRP', 'VBZ', 'RB', 'RB', 'JJ', 'IN', 'NN', '.']

# %%
# Important function, required to be implemented in the query expansion script.
# Extracts list of synonyms and antonyms from the wordnet.
def synonym_antonym_extractor(w_):
     # extracting relevant synonyms and antonym pairs.
     from nltk.corpus import wordnet
     synonyms = []
     antonyms = []
     for syn in wordnet.synsets(w_):
          for l in syn.lemmas():
               synonyms.append(str(l.name()).replace('_',' '))
               if l.antonyms():
                    antonyms.append(str(l.antonyms()[0].name()).replace('_',' '))
     return list(set(synonyms)), list(set(antonyms))
# testing out outputs of the synonym_antonym_extractor function.
# synonym_antonym_extractor('better')

# %%
# Must required and embeddings to be downloaded into the script.
# import statements and GloVe embeddings loading for word vectorization.
import gensim.downloader as api
# overview of all models in gensim: https://github.com/RaRe-Technologies/gensim-data
model_glove = api.load("glove-wiki-gigaword-300")
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded

# %%
# Important function required for the script you are making, for extract best
# synonym and antonym words. Second, it also calls synonym_antonym_extractor function in it.
# Also, it requires above loading of the module for its working.
# Getting 3 best synonyms and 2 best antonym pairs for a given 'ADJ'
def best_words_extractor(w_, syn_list, ann_list):
    # prepare dictionaries for scores of syn_list & ann_list with w_
    syns = []
    anns = []
    for s_ in syn_list:
        try:
            if model_glove.get_vector(s_) is not None and s_ != w_:
                syns.append(s_)
        except:
            pass
    # print(syns)
    for a_ in ann_list:
        try:
            if model_glove.get_vector(a_) is not None and a_ != w_:
                anns.append(a_)
        except:
            pass
    # print(anns)
    syn_score_dict = {}
    ann_score_dict = {}
    for s_ in syns:
        syn_score_dict[s_] = model_glove.distance(w_, s_)
    for a_ in anns:
        ann_score_dict[a_] = model_glove.distance(w_, a_)
    # getting only the top-k most similar synonyms and most dissimilar antonyms
    # values from the dictionaries and creating score permutations for them.
    syn_score_dict = {k: v for k, v in sorted(syn_score_dict.items(), key=lambda item: item[1])}
    # print(syn_score_dict)
    syn_score_dict = {k: syn_score_dict[k] for k in list(syn_score_dict)[:20]}
    # print(syn_score_dict)
    ann_score_dict = {k: v for k, v in sorted(ann_score_dict.items(), key=lambda item: item[1])}
    # print(ann_score_dict)
    ann_score_dict = {k: ann_score_dict[k] for k in list(ann_score_dict)[:20]}
    # print(ann_score_dict)
    syn_data = []
    ann_data = []
    c_ = 0
    for i, j in syn_score_dict.items():
        c_ = c_ + 1
        syn_data.append(i)
        if c_ >=3:
            break
    if len(syn_data) < 3:
        syn_data = ['good','well', 'best']
    c_ = 0
    for i, j in ann_score_dict.items():
        c_ = c_ + 1
        ann_data.append(i)
        if c_ >=1:
            break
    if len(ann_data) < 2:
        if len(ann_data) == 0:
            ann_data = ['worse','badly']
        if len(ann_data) == 1 and ann_data[0] != 'worse':
            ann_data.append('worse')
        if len(ann_data) == 1 and ann_data[0] == 'worse':
            ann_data.append('different')
    return syn_data, ann_data

# %%
# Testing the outputs for above defined functions.
# Specifically, 'synonym_antonym_extractor' and 'best_words_extractor' 
syns, anons = synonym_antonym_extractor('better')
print(syns)
print(anons)
print(best_words_extractor('better', syns, anons))
# Out:
# ['wagerer', 'serious', 'practiced', 'easily', 'in force', 'sound', 'honest', 'best', 'punter', 'honorable', 'unspoiled', 'substantially', 'skilful', 'skillful', 'undecomposed', 'near', 'expert', 'amend', 'salutary', 'comfortably', 'advantageously', 'effective', 'ameliorate', 'upright', 'bettor', 'intimately', 'adept', 'secure', 'well', 'in effect', 'respectable', 'beneficial', 'safe', 'good', 'improve', 'full', 'just', 'ripe', 'considerably', 'unspoilt', 'right', 'dear', 'estimable', 'dependable', 'proficient', 'break', 'better', 'meliorate']
# ['badly', 'ill', 'worse', 'bad', 'disadvantageously', 'evil', 'worsen']
# (['good', 'well', 'improve'], ['worse', 'different'])

# %%
# IMPORTANT: This function combined with above two synonym and antonym
# finding and generating function is required to generate the expanded queries.
# Return multiple expanded query versions.
# nouns only, top-3 synonyms and antonyms queries.
# Note: this is the final function that given an input query generates out
# series of various expanded queries as output.
def get_comparation_superlation_nouns(query):
    nouns_as_string = []
    nouns_only_string = []
    restricted_nouns_as_string = []
    doc = sp(query)
    annotations = ["CC", "CD", "JJ", "JJR", "JJS",
            "RB", "RBR", "RBS", "NN", "NNS", "NNP",
            "NNPS", "VB"]
    annotations_except_nouns = ["CC", "CD", "JJ", "JJR", "JJS",
            "RB", "RBR", "RBS", "VB"]
    annotations_nouns = ["NN", "NNS", "NNP", "NNPS", "VB"]
    adj_flg = 0
    adj_val = 'better' # default value, query objectives.
    # appending data into nouns as string
    for token in doc:
        if token.tag_ in annotations:
            nouns_as_string.append(token.text)
            if token.tag_ in annotations_except_nouns and adj_flg == 0:
                adj_val = token.text
                adj_flg = 1
            if token.tag_ not in annotations_except_nouns:
                restricted_nouns_as_string.append(token.text)
            if token.tag_ in annotations_nouns:
                nouns_only_string.append(token.text)

    # appending top-3 syns and anons to the query
    adj_val= adj_val.lower()
    syns, anons = synonym_antonym_extractor(adj_val)
    # print(syns, anons)
    if len(syns) == 0:
        syns, _ = synonym_antonym_extractor('different')
    if len(anons) == 0:
        _, anons = synonym_antonym_extractor('better')
    
    syns_fin, anons_fin = best_words_extractor(adj_val,syns, anons)
    
    # queries preprepartion
    base_query = " ".join(nouns_as_string)
    noun_query = " ".join(nouns_only_string)
    temp_query = " ".join(restricted_nouns_as_string)
    syn1_query = "".join(syns_fin[0]).strip() + " " + temp_query
    syn2_query = "".join(syns_fin[1]).strip() + " " + temp_query
    syn3_query = "".join(syns_fin[2]).strip() + " " + temp_query
    ant1_query = "".join(anons_fin[0]).strip() + " " + temp_query
    ant2_query = "".join(anons_fin[1]).strip() + " " + temp_query

    return base_query.strip(), noun_query.strip(), syn1_query.strip(), syn2_query.strip(), syn3_query.strip(), \
    ant1_query.strip(), ant2_query.strip()

# %%
# Sample example for testing out the function.
topics = [
    "What is the difference between sex and love?",
    "Which is the highest mountain in the world?",
    "Which is better, a laptop or a desktop?",
]
for q in topics:
    print(get_comparation_superlation_nouns(q))
    print('\n')
# Out:
# ('difference sex and love', 'difference sex love', 'different difference sex love', 'unlike difference sex love', 'dissimilar difference sex love', 'bad difference sex love', 'worse difference sex love')
#
#
# ('highest mountain world', 'mountain world', 'high mountain world', 'eminent mountain world', 'high-pitched mountain world', 'low mountain world', 'worse mountain world')
#
#
# ('better laptop or desktop', 'laptop desktop', 'good laptop desktop', 'well laptop desktop', 'improve laptop desktop', 'worse laptop desktop', 'different laptop desktop')

# %%
# Extensive sample testing example for getting out the function results.
topics_large = [
    "What is the difference between sex and love?",
    "Which is better, a laptop or a desktop?",
    "Which is better, Canon or Nikon?",
    "What are the best dish detergents?",
    "What are the best cities to live in?",
    "What is the longest river in the U.S.?",
    "Which is healthiest: coffee, green tea or black tea and why?",
    "What are the advantages and disadvantages of PHP over Python and vice versa?",
    "Why is Linux better than Windows?",
    "How to sleep better?",
    "Should I buy an LCD TV or a plasma TV?",
    "Train or plane? Which is the better choice?",
    "What is the highest mountain on Earth?",
    "Should one prefer Chinese medicine or Western medicine?",
    "What are the best washing machine brands?",
    "Should I buy or rent?",
    "Do you prefer cats or dogs, and why?",
    "What is the better way to grill outdoors: gas or charcoal?",
    "Which is better, MAC or PC?",
    "What is better: to use a brush or a sponge?",
    "Which is better, Linux or Microsoft?",
    "Which is better, Pepsi or Coke?",
    "What is better, Google search or Yahoo search?",
    "Which one is better, Netflix or Blockbuster?",
    "Which browser is better, Internet Explorer or Firefox?",
    "Which is a better vehicle: BMW or Audi?",
    "Which one is better, an electric stove or a gas stove?",
    "What planes are best, Boeing or Airbus?",
    "Which is better, Disneyland or Disney World?",
    "Should I buy an Xbox or a PlayStation?",
    "Which has more caffeine, coffee or tea?",
    "Which is better, LED or LCD Reception Displays?",
    "What is better: ASP or PHP?",
    "What is better for the environment, a real or a fake Christmas tree?",
    "Do you prefer tampons or pads?",
    "What IDE is better for Java: NetBeans or Eclipse?",
    "Is OpenGL better than Direct3D in terms of portability to different platforms?",
    "What are the differences between MySQL and PostgreSQL in performance?",
    "Is Java code more readable than code written in Scala?",
    "Which operating system has better performance: Windows 7 or Windows 8?",
    "Which smartphone has a better battery life: Xperia or iPhone?",
    "Which four wheel truck is better: Ford or Toyota?",
    "Should I prefer a Leica camera over Nikon for portrait photographs?",
    "Which company has a larger capitalization: Apple or Microsoft?",
    "Which laptop has a better durability: HP or Dell?",
    "Which beverage has more calories per glass: beer or cider?",
    "Is admission rate in Stanford higher than that of MIT?",
    "Is pasta healthier than pizza?",
    "Which city is more expensive to live in: San Francisco or New York?",
    "Whose salary is higher: basketball or soccer players?",
]
for q in topics_large[10:20]:
    print(get_comparation_superlation_nouns(q))
    # print('\n')
# Out:
# ('buy LCD TV or plasma TV', 'buy LCD TV plasma TV', 'purchase LCD TV plasma TV', 'steal LCD TV plasma TV', 'bargain LCD TV plasma TV', 'sell LCD TV plasma TV', 'worse LCD TV plasma TV')
# ('Train or plane better choice', 'Train plane choice', 'good Train plane choice', 'well Train plane choice', 'best Train plane choice', 'bad Train plane choice', 'worse Train plane choice')
# ('highest mountain Earth', 'mountain Earth', 'high mountain Earth', 'eminent mountain Earth', 'high-pitched mountain Earth', 'low mountain Earth', 'worse mountain Earth')
# ('prefer Chinese medicine or Western medicine', 'prefer medicine medicine', 'choose medicine medicine', 'opt medicine medicine', 'favor medicine medicine', 'worse medicine medicine', 'different medicine medicine')
# ('best washing machine brands', 'washing machine brands', 'better washing machine brands', 'good washing machine brands', 'well washing machine brands', 'worst washing machine brands', 'worse washing machine brands')
# ('buy or rent', 'buy rent', 'purchase', 'steal', 'bargain', 'sell', 'worse')
# ('prefer cats or dogs and', 'prefer cats dogs', 'choose cats dogs', 'opt cats dogs', 'favor cats dogs', 'worse cats dogs', 'different cats dogs')
# ('better way grill outdoors gas or charcoal', 'way grill gas charcoal', 'good way gas charcoal', 'well way gas charcoal', 'improve way gas charcoal', 'worse way gas charcoal', 'different way gas charcoal')
# ('better MAC or PC', 'MAC PC', 'good MAC PC', 'well MAC PC', 'improve MAC PC', 'worse MAC PC', 'different MAC PC')
# ('better use brush or sponge', 'use brush sponge', 'good brush sponge', 'well brush sponge', 'improve brush sponge', 'worse brush sponge', 'different brush sponge')

# %%
# Not required for building your script, it's used hear for testing baseline
# and voting based query expansion methods.
from xml.dom import minidom
# Define function for loading all the topics from the topics files.
def parse_xml(path):
  answer_list = []
  xmldoc = minidom.parse(path)
  itemlist = xmldoc.getElementsByTagName('topics')
  topic_list = itemlist[0].getElementsByTagName('topic')
  for topic in topic_list:
    tuple_for_add = tuple((topic.getElementsByTagName('number')[0].firstChild.nodeValue, topic.getElementsByTagName('title')[0].firstChild.nodeValue))
    answer_list.append(tuple_for_add)
  parsed=pd.DataFrame(answer_list, columns=["number","title"])
  return parsed

# preparing the list of topics and corresponding dataframe.
# topics_2020 = parse_xml("/content/drive/MyDrive/touche-2022-prototyping/topics-task-2.xml")
# topics_2021 = parse_xml("/content/drive/MyDrive/touche-2022-prototyping/topics-task2-51-100.xml")
topics_2022 = parse_xml("drive/MyDrive/touche-2022-prototyping/topics-task2-2022/topics-task2.xml")
touche_topics = topics_2022
touche_topics
# Out:
#    number                                              title
# 0       2            Which is better, a laptop or a desktop?
# 1       3                   Which is better, Canon or Nikon?
# 2       8  What are the advantages and disadvantages of P...
# 3       9                  Why is Linux better than Windows?
# 4      12        Train or plane? Which is the better choice?
# 5      14  Should one prefer Chinese medicine or Western ...
# 6      17               Do you prefer cats or dogs, and why?
# 7      18  What is the better way to grill outdoors: gas ...
# 8      19                        Which is better, MAC or PC?
# 9      22                    Which is better, Pepsi or Coke?
# 10     23     What is better, Google search or Yahoo search?
# 11     25  Which browser is better, Internet Explorer or ...
# 12     26            Which is a better vehicle: BMW or Audi?
# 13     27  Which one is better, an electric stove or a ga...
# 14     28            What planes are best, Boeing or Airbus?
# 15     30             Should I buy an Xbox or a PlayStation?
# 16     33                        What is better: ASP or PHP?
# 17     34  What is better for the environment, a real or ...
# 18     36  What IDE is better for Java: NetBeans or Eclipse?
# 19     37  Is OpenGL better than Direct3D in terms of por...
# 20     42  Which four wheel truck is better: Ford or Toyota?
# 21     43  Should I prefer a Leica camera over Nikon for ...
# 22     48                     Is pasta healthier than pizza?
# 23     51  What is better at reducing fever in children, ...
# 24     53              Should I buy steel or ceramic knives?
# 25     54  Is morning or afternoon sun the best for fruit...
# 26     55  What is better for back pain, chiropractic the...
# 27     56          Is Kenya or Tanzania better for a safari?
# 28     58       Which is better, Family Guy or The Simpsons?
# 29     59   Which is more difficult, skiing or snowboarding?
# 30     60            Why is basketball better than football?
# 31     61                 Who is stronger, Hulk or Superman?
# 32     62  Plastic pots or ceramic pots, which is better ...
# 33     67              Should I take the IELTS or the TOEFL?
# 34     68  Are online courses better than physical classr...
# 35     69  Who was a better boxer, Muhammad Ali or Joe Fr...
# 36     70  Which technology performs better: Apple's or G...
# 37     72  Who is better at learning a foreign language, ...
# 38     74             Which city is better, London or Paris?
# 39     76  Are artificial sweeteners better than white su...
# 40     77          Is it healthier to bake than to fry food?
# 41     78  Which algorithm is better, quicksort or merge ...
# 42     84             What is better, cow milk or goat milk?
# 43     86  I am planning to buy sneakers: Which are bette...
# 44     88        Should I major in philosophy or psychology?
# 45     91  When are random forest classifiers better than...
# 46     92  What are the pros and cons of wood vs. stone m...
# 47     93    Is rain water better than tap water for plants?
# 48     95  Which is more environmentally friendly, a hybr...
# 49    100      Should I learn Python or R for data analysis?

# %%
for q in touche_topics['title']:
    print(get_comparation_superlation_nouns(q))
# Out:
# ('better laptop or desktop', 'laptop desktop', 'good laptop desktop', 'well laptop desktop', 'improve laptop desktop', 'worse laptop desktop', 'different laptop desktop')
# ('better Canon or Nikon', 'Canon Nikon', 'good Canon Nikon', 'well Canon Nikon', 'improve Canon Nikon', 'worse Canon Nikon', 'different Canon Nikon')
# ('advantages and disadvantages PHP Python and vice versa', 'advantages disadvantages PHP Python vice', 'different advantages disadvantages PHP Python vice', 'unlike advantages disadvantages PHP Python vice', 'dissimilar advantages disadvantages PHP Python vice', 'bad advantages disadvantages PHP Python vice', 'worse advantages disadvantages PHP Python vice')
# ('Linux better Windows', 'Linux Windows', 'good Linux Windows', 'well Linux Windows', 'improve Linux Windows', 'worse Linux Windows', 'different Linux Windows')
# ('Train or plane better choice', 'Train plane choice', 'good Train plane choice', 'well Train plane choice', 'best Train plane choice', 'bad Train plane choice', 'worse Train plane choice')
# ('prefer Chinese medicine or Western medicine', 'prefer medicine medicine', 'choose medicine medicine', 'opt medicine medicine', 'favor medicine medicine', 'worse medicine medicine', 'different medicine medicine')
# ('prefer cats or dogs and', 'prefer cats dogs', 'choose cats dogs', 'opt cats dogs', 'favor cats dogs', 'worse cats dogs', 'different cats dogs')
# ('better way grill outdoors gas or charcoal', 'way grill gas charcoal', 'good way gas charcoal', 'well way gas charcoal', 'improve way gas charcoal', 'worse way gas charcoal', 'different way gas charcoal')
# ('better MAC or PC', 'MAC PC', 'good MAC PC', 'well MAC PC', 'improve MAC PC', 'worse MAC PC', 'different MAC PC')
# ('better Pepsi or Coke', 'Pepsi Coke', 'good Pepsi Coke', 'well Pepsi Coke', 'improve Pepsi Coke', 'worse Pepsi Coke', 'different Pepsi Coke')
# ('better Google search or Yahoo search', 'Google search Yahoo search', 'good Google search Yahoo search', 'well Google search Yahoo search', 'improve Google search Yahoo search', 'worse Google search Yahoo search', 'different Google search Yahoo search')
# ('browser better Internet Explorer or Firefox', 'browser Internet Explorer Firefox', 'good browser Internet Explorer Firefox', 'well browser Internet Explorer Firefox', 'improve browser Internet Explorer Firefox', 'worse browser Internet Explorer Firefox', 'different browser Internet Explorer Firefox')
# ('better vehicle BMW or Audi', 'vehicle BMW Audi', 'good vehicle BMW Audi', 'well vehicle BMW Audi', 'improve vehicle BMW Audi', 'worse vehicle BMW Audi', 'different vehicle BMW Audi')
# ('one better electric stove or gas stove', 'one stove gas stove', 'good one stove gas stove', 'well one stove gas stove', 'improve one stove gas stove', 'worse one stove gas stove', 'different one stove gas stove')
# ('planes best Boeing or Airbus', 'planes Boeing Airbus', 'better planes Boeing Airbus', 'good planes Boeing Airbus', 'well planes Boeing Airbus', 'worst planes Boeing Airbus', 'worse planes Boeing Airbus')
# ('buy Xbox or PlayStation', 'buy Xbox PlayStation', 'purchase Xbox PlayStation', 'steal Xbox PlayStation', 'bargain Xbox PlayStation', 'sell Xbox PlayStation', 'worse Xbox PlayStation')
# ('better ASP or PHP', 'ASP PHP', 'good ASP PHP', 'well ASP PHP', 'improve ASP PHP', 'worse ASP PHP', 'different ASP PHP')
# ('better environment real or fake Christmas tree', 'environment Christmas tree', 'good environment Christmas tree', 'well environment Christmas tree', 'improve environment Christmas tree', 'worse environment Christmas tree', 'different environment Christmas tree')
# ('IDE better Java NetBeans or Eclipse', 'IDE Java NetBeans Eclipse', 'good IDE Java NetBeans Eclipse', 'well IDE Java NetBeans Eclipse', 'improve IDE Java NetBeans Eclipse', 'worse IDE Java NetBeans Eclipse', 'different IDE Java NetBeans Eclipse')
# ('OpenGL better terms portability different platforms', 'OpenGL terms portability platforms', 'good OpenGL terms portability platforms', 'well OpenGL terms portability platforms', 'improve OpenGL terms portability platforms', 'worse OpenGL terms portability platforms', 'different OpenGL terms portability platforms')
# ('four wheel truck better Ford or Toyota', 'wheel truck Ford Toyota', '4 wheel truck Ford Toyota', 'quartet wheel truck Ford Toyota', 'iv wheel truck Ford Toyota', 'badly wheel truck Ford Toyota', 'worse wheel truck Ford Toyota')
# ('prefer Leica camera Nikon portrait photographs', 'prefer Leica camera Nikon portrait photographs', 'choose Leica camera Nikon portrait photographs', 'opt Leica camera Nikon portrait photographs', 'favor Leica camera Nikon portrait photographs', 'worse Leica camera Nikon portrait photographs', 'different Leica camera Nikon portrait photographs')
# ('pasta healthier pizza', 'pasta pizza', 'healthy pasta pizza', 'fitter pasta pizza', 'salubrious pasta pizza', 'unhealthy pasta pizza', 'worse pasta pizza')
# ('better fever children Ibuprofen or Aspirin', 'fever children Ibuprofen Aspirin', 'good fever children Ibuprofen Aspirin', 'well fever children Ibuprofen Aspirin', 'improve fever children Ibuprofen Aspirin', 'worse fever children Ibuprofen Aspirin', 'different fever children Ibuprofen Aspirin')
# ('buy steel or ceramic knives', 'buy steel knives', 'purchase steel knives', 'steal steel knives', 'bargain steel knives', 'sell steel knives', 'worse steel knives')
# ('morning or afternoon sun best fruit trees', 'morning afternoon sun fruit trees', 'good morning afternoon sun fruit trees', 'well morning afternoon sun fruit trees', 'best morning afternoon sun fruit trees', 'bad morning afternoon sun fruit trees', 'worse morning afternoon sun fruit trees')
# ('better back pain chiropractic therapy or physical therapy', 'pain therapy therapy', 'good pain therapy therapy', 'well pain therapy therapy', 'improve pain therapy therapy', 'worse pain therapy therapy', 'different pain therapy therapy')
# ('Kenya or Tanzania better safari', 'Kenya Tanzania safari', 'good Kenya Tanzania safari', 'well Kenya Tanzania safari', 'best Kenya Tanzania safari', 'bad Kenya Tanzania safari', 'worse Kenya Tanzania safari')
# ('better Family Guy or Simpsons', 'Family Guy Simpsons', 'good Family Guy Simpsons', 'well Family Guy Simpsons', 'improve Family Guy Simpsons', 'worse Family Guy Simpsons', 'different Family Guy Simpsons')
# ('more difficult or snowboarding', 'snowboarding', 'good snowboarding', 'well snowboarding', 'best snowboarding', 'less snowboarding', 'worse snowboarding')
# ('basketball better football', 'basketball football', 'good basketball football', 'well basketball football', 'improve basketball football', 'worse basketball football', 'different basketball football')
# ('stronger Hulk or Superman', 'Hulk Superman', 'strong Hulk Superman', 'solid Hulk Superman', 'hard Hulk Superman', 'weak Hulk Superman', 'worse Hulk Superman')
# ('Plastic pots or ceramic pots better terms plant health', 'pots pots terms plant health', 'moldable pots pots terms plant health', 'pliant pots pots terms plant health', 'shaping pots pots terms plant health', 'bad pots pots terms plant health', 'worse pots pots terms plant health')
# ('take IELTS or TOEFL', 'take IELTS TOEFL', 'make IELTS TOEFL', 'get IELTS TOEFL', 'need IELTS TOEFL', 'give IELTS TOEFL', 'worse IELTS TOEFL')
# ('online courses better physical classrooms', 'courses classrooms', 'good courses classrooms', 'well courses classrooms', 'best courses classrooms', 'off-line courses classrooms', 'worse courses classrooms')
# ('better boxer Muhammad Ali or Joe Frazier', 'boxer Muhammad Ali Joe Frazier', 'good boxer Muhammad Ali Joe Frazier', 'well boxer Muhammad Ali Joe Frazier', 'improve boxer Muhammad Ali Joe Frazier', 'worse boxer Muhammad Ali Joe Frazier', 'different boxer Muhammad Ali Joe Frazier')
# ('technology better Apple or Google', 'technology Apple Google', 'good technology Apple Google', 'well technology Apple Google', 'improve technology Apple Google', 'worse technology Apple Google', 'different technology Apple Google')
# ('better foreign language kids or adults', 'language kids adults', 'good language kids adults', 'well language kids adults', 'improve language kids adults', 'worse language kids adults', 'different language kids adults')
# ('city better London or Paris', 'city London Paris', 'good city London Paris', 'well city London Paris', 'improve city London Paris', 'worse city London Paris', 'different city London Paris')
# ('artificial sweeteners better white sugar', 'sweeteners sugar', 'contrived sweeteners sugar', 'hokey sweeteners sugar', 'unreal sweeteners sugar', 'natural sweeteners sugar', 'worse sweeteners sugar')
# ('healthier bake fry food', 'bake food', 'healthy food', 'fitter food', 'salubrious food', 'unhealthy food', 'worse food')
# ('algorithm better quicksort or merge sort', 'algorithm quicksort merge sort', 'good algorithm sort', 'well algorithm sort', 'improve algorithm sort', 'worse algorithm sort', 'different algorithm sort')
# ('better cow milk or goat milk', 'cow milk goat milk', 'good cow milk goat milk', 'well cow milk goat milk', 'improve cow milk goat milk', 'worse cow milk goat milk', 'different cow milk goat milk')
# ('buy sneakers better Adidas or Nike', 'buy sneakers Adidas Nike', 'purchase sneakers Adidas Nike', 'steal sneakers Adidas Nike', 'bargain sneakers Adidas Nike', 'sell sneakers Adidas Nike', 'worse sneakers Adidas Nike')
# ('major philosophy or psychology', 'major philosophy psychology', 'good philosophy psychology', 'well philosophy psychology', 'best philosophy psychology', 'minor philosophy psychology', 'worse philosophy psychology')
# ('random forest classifiers better decision trees', 'forest classifiers decision trees', 'good forest classifiers decision trees', 'well forest classifiers decision trees', 'best forest classifiers decision trees', 'worse forest classifiers decision trees', 'badly forest classifiers decision trees')
# ('pros and cons wood stone mulch', 'pros cons wood stone mulch', 'different pros cons wood stone mulch', 'unlike pros cons wood stone mulch', 'dissimilar pros cons wood stone mulch', 'bad pros cons wood stone mulch', 'worse pros cons wood stone mulch')
# ('rain water better tap water plants', 'rain water tap water plants', 'good rain water tap water plants', 'well rain water tap water plants', 'improve rain water tap water plants', 'worse rain water tap water plants', 'different rain water tap water plants')
# ('more environmentally friendly hybrid or diesel', 'hybrid diesel', 'good hybrid diesel', 'well hybrid diesel', 'best hybrid diesel', 'less hybrid diesel', 'worse hybrid diesel')
# ('learn Python or R data analysis', 'learn Python R data analysis', 'teach Python R data analysis', 'take Python R data analysis', 'see Python R data analysis', 'bad Python R data analysis', 'worse Python R data analysis')

# %%
# Some acronyms in the query might be an issue during the retrieval
# hardcoding domain knowledge with their full forms for retrieval.
acr_to_full_word = {'PC': 'Personal Computer (PC)', 'MAC': 'MacBook (MAC)', 'ASP': 'Active Server Pages (ASP)'
                    ,'PHP': 'Hypertext Preprocessor (PHP)' , 'IDE': 'Integrated Development Environment (IDE)'
                    ,'R': 'R (programming language)'
                    ,'IELTS': 'International English Language Testing System (IELTS)'
                    ,'TOEFL': 'Test of English as a Foreign Language (TOEFL)'
                  }

def acr_replace(query):
    for acr_, full_form_ in acr_to_full_word.items():
        full_query = query.replace(acr_, full_form_)
        query = full_query
    return full_query


print(acr_replace('Should I learn Python or R for data analysis?'))
print(acr_replace('What is better: ASP or PHP?'))
print(acr_replace('What IDE is better for Java: NetBeans or Eclipse?'))
print(acr_replace('Should I take the IELTS or the TOEFL?'))
print(acr_replace('What IDE is better for Java: NetBeans or Eclipse?'))
# Out:
# Should I learn Python or R (programming language) for data analysis?
# What is better: Active Server Pages (ASP) or Hypertext Preprocessor (PHP)?
# What Integrated Development Environment (IDE) is better for Java: NetBeans or Eclipse?
# Should I take the International English Language Testing System (IELTS) or the Test of English as a Foreign Language (TOEFL)?
# What Integrated Development Environment (IDE) is better for Java: NetBeans or Eclipse?

# %%
# Loading the pseudo relevance document from Pujit's topics file as reference.
pseudo_topics = pd.read_csv('/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/Touche/topics-task2-psuedo_relevance.csv')

# %%
# Getting output of pseudo relevance query dataframe.
pseudo_topics.head()
# Out:
#    Number                                              Title          Objects  \
# 0       2            Which is better, a laptop or a desktop?  laptop, desktop
# 1       3                   Which is better, Canon or Nikon?     Canon, Nikon
# 2       8  What are the advantages and disadvantages of P...      PHP, Python
# 3       9                  Why is Linux better than Windows?   Linux, Windows
# 4      12        Train or plane? Which is the better choice?     Train, plane
#
#                                                  New  Frequency
# 0   Which is better, a laptop or a desktop? computer         39
# 1                Which is better, Canon or Nikon? vs         42
# 2  What are the advantages and disadvantages of P...         45
# 3         Why is Linux better than Windows? software         12
# 4  Train or plane? Which is the better choice? tr...         25

# %%
 # Not required for the script, building the dataframe.
 touche_topics['title'] = touche_topics['title'].apply(lambda x: x.strip())
 touche_topics['title_acr_full'] = touche_topics['title'].apply(lambda x: acr_replace(x.strip()))
 touche_topics['title_pseudo'] = pseudo_topics['New'].apply(lambda x: get_comparation_superlation_nouns(x)[0])
 touche_topics['query_base'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[0])
 touche_topics['query_noun'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[1])
 touche_topics['query_synonym1'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[2])
 touche_topics['query_synonym2'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[3])
 touche_topics['query_synonym3'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[4])
 touche_topics['query_antonym1'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[5])
 touche_topics['query_antonym2'] = touche_topics['title'].apply(lambda x: get_comparation_superlation_nouns(x)[6])

# %%
# Not required for the script, getting the dataframe output.
touche_topics
# Out:
#    number                                              title  \
# 0       2            Which is better, a laptop or a desktop?
# 1       3                   Which is better, Canon or Nikon?
# 2       8  What are the advantages and disadvantages of P...
# 3       9                  Why is Linux better than Windows?
# 4      12        Train or plane? Which is the better choice?
# 5      14  Should one prefer Chinese medicine or Western ...
# 6      17               Do you prefer cats or dogs, and why?
# 7      18  What is the better way to grill outdoors: gas ...
# 8      19                        Which is better, MAC or PC?
# 9      22                    Which is better, Pepsi or Coke?
# 10     23     What is better, Google search or Yahoo search?
# 11     25  Which browser is better, Internet Explorer or ...
# 12     26            Which is a better vehicle: BMW or Audi?
# 13     27  Which one is better, an electric stove or a ga...
# 14     28            What planes are best, Boeing or Airbus?
# 15     30             Should I buy an Xbox or a PlayStation?
# 16     33                        What is better: ASP or PHP?
# 17     34  What is better for the environment, a real or ...
# 18     36  What IDE is better for Java: NetBeans or Eclipse?
# 19     37  Is OpenGL better than Direct3D in terms of por...
# 20     42  Which four wheel truck is better: Ford or Toyota?
# 21     43  Should I prefer a Leica camera over Nikon for ...
# 22     48                     Is pasta healthier than pizza?
# 23     51  What is better at reducing fever in children, ...
# 24     53              Should I buy steel or ceramic knives?
# 25     54  Is morning or afternoon sun the best for fruit...
# 26     55  What is better for back pain, chiropractic the...
# 27     56          Is Kenya or Tanzania better for a safari?
# 28     58       Which is better, Family Guy or The Simpsons?
# 29     59   Which is more difficult, skiing or snowboarding?
# 30     60            Why is basketball better than football?
# 31     61                 Who is stronger, Hulk or Superman?
# 32     62  Plastic pots or ceramic pots, which is better ...
# 33     67              Should I take the IELTS or the TOEFL?
# 34     68  Are online courses better than physical classr...
# 35     69  Who was a better boxer, Muhammad Ali or Joe Fr...
# 36     70  Which technology performs better: Apple's or G...
# 37     72  Who is better at learning a foreign language, ...
# 38     74             Which city is better, London or Paris?
# 39     76  Are artificial sweeteners better than white su...
# 40     77          Is it healthier to bake than to fry food?
# 41     78  Which algorithm is better, quicksort or merge ...
# 42     84             What is better, cow milk or goat milk?
# 43     86  I am planning to buy sneakers: Which are bette...
# 44     88        Should I major in philosophy or psychology?
# 45     91  When are random forest classifiers better than...
# 46     92  What are the pros and cons of wood vs. stone m...
# 47     93    Is rain water better than tap water for plants?
# 48     95  Which is more environmentally friendly, a hybr...
# 49    100      Should I learn Python or R for data analysis?
#
#                                        title_acr_full  \
# 0             Which is better, a laptop or a desktop?
# 1                    Which is better, Canon or Nikon?
# 2   What are the advantages and disadvantages of H...
# 3                   Why is Linux better than Windows?
# 4         Train or plane? Which is the better choice?
# 5   Should one prefer Chinese medicine or Western ...
# 6                Do you prefer cats or dogs, and why?
# 7   What is the better way to grill outdoors: gas ...
# 8   Which is better, MacBook (MAC) or Personal Com...
# 9                     Which is better, Pepsi or Coke?
# 10     What is better, Google search or Yahoo search?
# 11  Which browser is better, Internet Explorer or ...
# 12            Which is a better vehicle: BMW or Audi?
# 13  Which one is better, an electric stove or a ga...
# 14            What planes are best, Boeing or Airbus?
# 15             Should I buy an Xbox or a PlayStation?
# 16  What is better: Active Server Pages (ASP) or H...
# 17  What is better for the environment, a real or ...
# 18  What Integrated Development Environment (IDE) ...
# 19  Is OpenGL better than Direct3D in terms of por...
# 20  Which four wheel truck is better: Ford or Toyota?
# 21  Should I prefer a Leica camera over Nikon for ...
# 22                     Is pasta healthier than pizza?
# 23  What is better at reducing fever in children, ...
# 24              Should I buy steel or ceramic knives?
# 25  Is morning or afternoon sun the best for fruit...
# 26  What is better for back pain, chiropractic the...
# 27          Is Kenya or Tanzania better for a safari?
# 28       Which is better, Family Guy or The Simpsons?
# 29   Which is more difficult, skiing or snowboarding?
# 30            Why is basketball better than football?
# 31                 Who is stronger, Hulk or Superman?
# 32  Plastic pots or ceramic pots, which is better ...
# 33  Should I take the International English Langua...
# 34  Are online courses better than physical classr...
# 35  Who was a better boxer, Muhammad Ali or Joe Fr...
# 36  Which technology performs better: Apple's or G...
# 37  Who is better at learning a foreign language, ...
# 38             Which city is better, London or Paris?
# 39  Are artificial sweeteners better than white su...
# 40          Is it healthier to bake than to fry food?
# 41  Which algorithm is better, quicksort or merge ...
# 42             What is better, cow milk or goat milk?
# 43  I am planning to buy sneakers: Which are bette...
# 44        Should I major in philosophy or psychology?
# 45  When are random forest classifiers better than...
# 46  What are the pros and cons of wood vs. stone m...
# 47    Is rain water better than tap water for plants?
# 48  Which is more environmentally friendly, a hybr...
# 49  Should I learn Python or R (programming langua...
#
#                                          title_pseudo  \
# 0                   better laptop or desktop computer
# 1                               better Canon or Nikon
# 2   advantages and disadvantages PHP Python and vi...
# 3                       Linux better Windows software
# 4                 Train or plane better choice travel
# 5   prefer Chinese medicine or Western medicine pe...
# 6                      prefer cats or dogs and people
# 7           better way grill outdoors gas or charcoal
# 8                            better MAC or PC windows
# 9                          better Pepsi or Coke taste
# 10        better Google search or Yahoo search engine
# 11        browser better Internet Explorer or Firefox
# 12                     better vehicle BMW or Audi car
# 13       one better electric stove or gas stove sauna
# 14              planes best Boeing or Airbus aircraft
# 15                        buy Xbox or PlayStation one
# 16                              better ASP or PHP net
# 17  better environment real or fake Christmas tree...
# 18                IDE better Java NetBeans or Eclipse
# 19  OpenGL better terms portability different plat...
# 20       four wheel truck better Ford or Toyota drive
# 21  prefer Leica camera Nikon portrait photographs...
# 22                        pasta healthier pizza sauce
# 23     better fever children Ibuprofen or Aspirin use
# 24                 buy steel or ceramic knives knives
# 25    morning or afternoon sun best fruit trees apple
# 26  better back pain chiropractic therapy or physi...
# 27             Kenya or Tanzania better safari africa
# 28                   better Family Guy or Simpsons pm
# 29              more difficult or snowboarding powder
# 30                basketball better football baseball
# 31                          stronger Hulk or Superman
# 32  Plastic pots or ceramic pots better terms plan...
# 33                        take IELTS or TOEFL english
# 34  online courses better physical classrooms stud...
# 35     better boxer Muhammad Ali or Joe Frazier fight
# 36        technology better Apple or Google microsoft
# 37    better foreign language kids or adults children
# 38                city better London or Paris dynamic
# 39   artificial sweeteners better white sugar natural
# 40                        healthier bake fry food fat
# 41           algorithm better quicksort or merge sort
# 42                   better cow milk or goat milk fat
# 43           buy sneakers better Adidas or Nike shoes
# 44            major philosophy or psychology students
# 45  random forest classifiers better decision tree...
# 46                pros and cons wood stone mulch soil
# 47             rain water better tap water plants use
# 48  more environmentally friendly hybrid or diesel...
# 49                learn Python or R data analysis use
#
#                                            query_base  \
# 0                            better laptop or desktop
# 1                               better Canon or Nikon
# 2   advantages and disadvantages PHP Python and vi...
# 3                                Linux better Windows
# 4                        Train or plane better choice
# 5         prefer Chinese medicine or Western medicine
# 6                             prefer cats or dogs and
# 7           better way grill outdoors gas or charcoal
# 8                                    better MAC or PC
# 9                                better Pepsi or Coke
# 10               better Google search or Yahoo search
# 11        browser better Internet Explorer or Firefox
# 12                         better vehicle BMW or Audi
# 13             one better electric stove or gas stove
# 14                       planes best Boeing or Airbus
# 15                            buy Xbox or PlayStation
# 16                                  better ASP or PHP
# 17     better environment real or fake Christmas tree
# 18                IDE better Java NetBeans or Eclipse
# 19  OpenGL better terms portability different plat...
# 20             four wheel truck better Ford or Toyota
# 21     prefer Leica camera Nikon portrait photographs
# 22                              pasta healthier pizza
# 23         better fever children Ibuprofen or Aspirin
# 24                        buy steel or ceramic knives
# 25          morning or afternoon sun best fruit trees
# 26  better back pain chiropractic therapy or physi...
# 27                    Kenya or Tanzania better safari
# 28                      better Family Guy or Simpsons
# 29                     more difficult or snowboarding
# 30                         basketball better football
# 31                          stronger Hulk or Superman
# 32  Plastic pots or ceramic pots better terms plan...
# 33                                take IELTS or TOEFL
# 34          online courses better physical classrooms
# 35           better boxer Muhammad Ali or Joe Frazier
# 36                  technology better Apple or Google
# 37             better foreign language kids or adults
# 38                        city better London or Paris
# 39           artificial sweeteners better white sugar
# 40                            healthier bake fry food
# 41           algorithm better quicksort or merge sort
# 42                       better cow milk or goat milk
# 43                 buy sneakers better Adidas or Nike
# 44                     major philosophy or psychology
# 45    random forest classifiers better decision trees
# 46                     pros and cons wood stone mulch
# 47                 rain water better tap water plants
# 48     more environmentally friendly hybrid or diesel
# 49                    learn Python or R data analysis
#
#                                         query_noun  \
# 0                                   laptop desktop
# 1                                      Canon Nikon
# 2         advantages disadvantages PHP Python vice
# 3                                    Linux Windows
# 4                               Train plane choice
# 5                         prefer medicine medicine
# 6                                 prefer cats dogs
# 7                           way grill gas charcoal
# 8                                           MAC PC
# 9                                       Pepsi Coke
# 10                      Google search Yahoo search
# 11               browser Internet Explorer Firefox
# 12                                vehicle BMW Audi
# 13                             one stove gas stove
# 14                            planes Boeing Airbus
# 15                            buy Xbox PlayStation
# 16                                         ASP PHP
# 17                      environment Christmas tree
# 18                       IDE Java NetBeans Eclipse
# 19              OpenGL terms portability platforms
# 20                         wheel truck Ford Toyota
# 21  prefer Leica camera Nikon portrait photographs
# 22                                     pasta pizza
# 23                fever children Ibuprofen Aspirin
# 24                                buy steel knives
# 25               morning afternoon sun fruit trees
# 26                            pain therapy therapy
# 27                           Kenya Tanzania safari
# 28                             Family Guy Simpsons
# 29                                    snowboarding
# 30                             basketball football
# 31                                   Hulk Superman
# 32                    pots pots terms plant health
# 33                                take IELTS TOEFL
# 34                              courses classrooms
# 35                  boxer Muhammad Ali Joe Frazier
# 36                         technology Apple Google
# 37                            language kids adults
# 38                               city London Paris
# 39                                sweeteners sugar
# 40                                       bake food
# 41                  algorithm quicksort merge sort
# 42                              cow milk goat milk
# 43                        buy sneakers Adidas Nike
# 44                     major philosophy psychology
# 45               forest classifiers decision trees
# 46                      pros cons wood stone mulch
# 47                     rain water tap water plants
# 48                                   hybrid diesel
# 49                    learn Python R data analysis
#
#                                        query_synonym1  \
# 0                                 good laptop desktop
# 1                                    good Canon Nikon
# 2   different advantages disadvantages PHP Python ...
# 3                                  good Linux Windows
# 4                             good Train plane choice
# 5                            choose medicine medicine
# 6                                    choose cats dogs
# 7                               good way gas charcoal
# 8                                         good MAC PC
# 9                                     good Pepsi Coke
# 10                    good Google search Yahoo search
# 11             good browser Internet Explorer Firefox
# 12                              good vehicle BMW Audi
# 13                           good one stove gas stove
# 14                        better planes Boeing Airbus
# 15                          purchase Xbox PlayStation
# 16                                       good ASP PHP
# 17                    good environment Christmas tree
# 18                     good IDE Java NetBeans Eclipse
# 19            good OpenGL terms portability platforms
# 20                          4 wheel truck Ford Toyota
# 21     choose Leica camera Nikon portrait photographs
# 22                                healthy pasta pizza
# 23              good fever children Ibuprofen Aspirin
# 24                              purchase steel knives
# 25             good morning afternoon sun fruit trees
# 26                          good pain therapy therapy
# 27                         good Kenya Tanzania safari
# 28                           good Family Guy Simpsons
# 29                                  good snowboarding
# 30                           good basketball football
# 31                               strong Hulk Superman
# 32              moldable pots pots terms plant health
# 33                                   make IELTS TOEFL
# 34                            good courses classrooms
# 35                good boxer Muhammad Ali Joe Frazier
# 36                       good technology Apple Google
# 37                          good language kids adults
# 38                             good city London Paris
# 39                         contrived sweeteners sugar
# 40                                       healthy food
# 41                                good algorithm sort
# 42                            good cow milk goat milk
# 43                      purchase sneakers Adidas Nike
# 44                         good philosophy psychology
# 45             good forest classifiers decision trees
# 46               different pros cons wood stone mulch
# 47                   good rain water tap water plants
# 48                                 good hybrid diesel
# 49                       teach Python R data analysis
#
#                                      query_synonym2  \
# 0                               well laptop desktop
# 1                                  well Canon Nikon
# 2   unlike advantages disadvantages PHP Python vice
# 3                                well Linux Windows
# 4                           well Train plane choice
# 5                             opt medicine medicine
# 6                                     opt cats dogs
# 7                             well way gas charcoal
# 8                                       well MAC PC
# 9                                   well Pepsi Coke
# 10                  well Google search Yahoo search
# 11           well browser Internet Explorer Firefox
# 12                            well vehicle BMW Audi
# 13                         well one stove gas stove
# 14                        good planes Boeing Airbus
# 15                           steal Xbox PlayStation
# 16                                     well ASP PHP
# 17                  well environment Christmas tree
# 18                   well IDE Java NetBeans Eclipse
# 19          well OpenGL terms portability platforms
# 20                  quartet wheel truck Ford Toyota
# 21      opt Leica camera Nikon portrait photographs
# 22                               fitter pasta pizza
# 23            well fever children Ibuprofen Aspirin
# 24                               steal steel knives
# 25           well morning afternoon sun fruit trees
# 26                        well pain therapy therapy
# 27                       well Kenya Tanzania safari
# 28                         well Family Guy Simpsons
# 29                                well snowboarding
# 30                         well basketball football
# 31                              solid Hulk Superman
# 32              pliant pots pots terms plant health
# 33                                  get IELTS TOEFL
# 34                          well courses classrooms
# 35              well boxer Muhammad Ali Joe Frazier
# 36                     well technology Apple Google
# 37                        well language kids adults
# 38                           well city London Paris
# 39                           hokey sweeteners sugar
# 40                                      fitter food
# 41                              well algorithm sort
# 42                          well cow milk goat milk
# 43                       steal sneakers Adidas Nike
# 44                       well philosophy psychology
# 45           well forest classifiers decision trees
# 46                unlike pros cons wood stone mulch
# 47                 well rain water tap water plants
# 48                               well hybrid diesel
# 49                      take Python R data analysis
#
#                                        query_synonym3  \
# 0                              improve laptop desktop
# 1                                 improve Canon Nikon
# 2   dissimilar advantages disadvantages PHP Python...
# 3                               improve Linux Windows
# 4                             best Train plane choice
# 5                             favor medicine medicine
# 6                                     favor cats dogs
# 7                            improve way gas charcoal
# 8                                      improve MAC PC
# 9                                  improve Pepsi Coke
# 10                 improve Google search Yahoo search
# 11          improve browser Internet Explorer Firefox
# 12                           improve vehicle BMW Audi
# 13                        improve one stove gas stove
# 14                          well planes Boeing Airbus
# 15                           bargain Xbox PlayStation
# 16                                    improve ASP PHP
# 17                 improve environment Christmas tree
# 18                  improve IDE Java NetBeans Eclipse
# 19         improve OpenGL terms portability platforms
# 20                         iv wheel truck Ford Toyota
# 21      favor Leica camera Nikon portrait photographs
# 22                             salubrious pasta pizza
# 23           improve fever children Ibuprofen Aspirin
# 24                               bargain steel knives
# 25             best morning afternoon sun fruit trees
# 26                       improve pain therapy therapy
# 27                         best Kenya Tanzania safari
# 28                        improve Family Guy Simpsons
# 29                                  best snowboarding
# 30                        improve basketball football
# 31                                 hard Hulk Superman
# 32               shaping pots pots terms plant health
# 33                                   need IELTS TOEFL
# 34                            best courses classrooms
# 35             improve boxer Muhammad Ali Joe Frazier
# 36                    improve technology Apple Google
# 37                       improve language kids adults
# 38                          improve city London Paris
# 39                            unreal sweeteners sugar
# 40                                    salubrious food
# 41                             improve algorithm sort
# 42                         improve cow milk goat milk
# 43                       bargain sneakers Adidas Nike
# 44                         best philosophy psychology
# 45             best forest classifiers decision trees
# 46              dissimilar pros cons wood stone mulch
# 47                improve rain water tap water plants
# 48                                 best hybrid diesel
# 49                         see Python R data analysis
#
#                                    query_antonym1  \
# 0                            worse laptop desktop
# 1                               worse Canon Nikon
# 2    bad advantages disadvantages PHP Python vice
# 3                             worse Linux Windows
# 4                          bad Train plane choice
# 5                         worse medicine medicine
# 6                                 worse cats dogs
# 7                          worse way gas charcoal
# 8                                    worse MAC PC
# 9                                worse Pepsi Coke
# 10               worse Google search Yahoo search
# 11        worse browser Internet Explorer Firefox
# 12                         worse vehicle BMW Audi
# 13                      worse one stove gas stove
# 14                     worst planes Boeing Airbus
# 15                          sell Xbox PlayStation
# 16                                  worse ASP PHP
# 17               worse environment Christmas tree
# 18                worse IDE Java NetBeans Eclipse
# 19       worse OpenGL terms portability platforms
# 20                  badly wheel truck Ford Toyota
# 21  worse Leica camera Nikon portrait photographs
# 22                          unhealthy pasta pizza
# 23         worse fever children Ibuprofen Aspirin
# 24                              sell steel knives
# 25          bad morning afternoon sun fruit trees
# 26                     worse pain therapy therapy
# 27                      bad Kenya Tanzania safari
# 28                      worse Family Guy Simpsons
# 29                              less snowboarding
# 30                      worse basketball football
# 31                             weak Hulk Superman
# 32               bad pots pots terms plant health
# 33                               give IELTS TOEFL
# 34                    off-line courses classrooms
# 35           worse boxer Muhammad Ali Joe Frazier
# 36                  worse technology Apple Google
# 37                     worse language kids adults
# 38                        worse city London Paris
# 39                       natural sweeteners sugar
# 40                                 unhealthy food
# 41                           worse algorithm sort
# 42                       worse cow milk goat milk
# 43                      sell sneakers Adidas Nike
# 44                    minor philosophy psychology
# 45        worse forest classifiers decision trees
# 46                 bad pros cons wood stone mulch
# 47              worse rain water tap water plants
# 48                             less hybrid diesel
# 49                     bad Python R data analysis
#
#                                        query_antonym2
# 0                            different laptop desktop
# 1                               different Canon Nikon
# 2      worse advantages disadvantages PHP Python vice
# 3                             different Linux Windows
# 4                            worse Train plane choice
# 5                         different medicine medicine
# 6                                 different cats dogs
# 7                          different way gas charcoal
# 8                                    different MAC PC
# 9                                different Pepsi Coke
# 10               different Google search Yahoo search
# 11        different browser Internet Explorer Firefox
# 12                         different vehicle BMW Audi
# 13                      different one stove gas stove
# 14                         worse planes Boeing Airbus
# 15                             worse Xbox PlayStation
# 16                                  different ASP PHP
# 17               different environment Christmas tree
# 18                different IDE Java NetBeans Eclipse
# 19       different OpenGL terms portability platforms
# 20                      worse wheel truck Ford Toyota
# 21  different Leica camera Nikon portrait photographs
# 22                                  worse pasta pizza
# 23         different fever children Ibuprofen Aspirin
# 24                                 worse steel knives
# 25            worse morning afternoon sun fruit trees
# 26                     different pain therapy therapy
# 27                        worse Kenya Tanzania safari
# 28                      different Family Guy Simpsons
# 29                                 worse snowboarding
# 30                      different basketball football
# 31                                worse Hulk Superman
# 32                 worse pots pots terms plant health
# 33                                  worse IELTS TOEFL
# 34                           worse courses classrooms
# 35           different boxer Muhammad Ali Joe Frazier
# 36                  different technology Apple Google
# 37                     different language kids adults
# 38                        different city London Paris
# 39                             worse sweeteners sugar
# 40                                         worse food
# 41                           different algorithm sort
# 42                       different cow milk goat milk
# 43                         worse sneakers Adidas Nike
# 44                        worse philosophy psychology
# 45            badly forest classifiers decision trees
# 46                   worse pros cons wood stone mulch
# 47              different rain water tap water plants
# 48                                worse hybrid diesel
# 49                       worse Python R data analysis

# %%
# Not required for the script, just saving the above dataframe in 'csv' format.
# touche_topics.to_csv("/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/touche_topics_query_expansion.csv", index=False)
# Changing the final saved file name for pseudo relevance query retrieval.
touche_topics.to_csv("/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/pseudo_touche_topics_query_expansion.csv", index=False)

# %%
# Metric Evaluation for the query expansion approach.
# 1. Loading the data from the touche topics file.
# ---
# ---
# IMPORTANT, relevant for script: We perform multiple retrievals for all the expanded queries.
# Note: This might be an important modification required from the current script perspective.

# Second, we use retrieval of our main query as driving matcher, and check whether for each query
# the document is retrieved by any other of the pooled queries (at least 1, threshold).
# If yes, we keep those documents. (We do it for first 1K documents, but we will essentially end up with ,1k documents)

# After this, we select first-k relevant documents from each of the pool queries 
# The selected number of retrieved documents is optimized based on practical experience with retrieval count tuning.

# Finally, those first-k relevant documents that are not present in our list from the second step are appended until 1.5k
# document count is reached. This logic is implemented in the form of a dictionary iterator in the upcoming cells.
# ---
# ---
# 2. Loading the corresponding queries into List, making predictions of k=275 (min) on the built index.
# 3. Merging Logic: For additional queries, remove the matching documents & keep only first non-existing docs.
# 4. Evaluation Metric: Average coverage/recall calculation for the voting based query expansion.

# %%
# Import statements for retrieval evaluation.
import pandas as pd

# %%
# Loading the saved query expansion dataframe.
touche_topics = pd.read_csv('/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/pseudo_touche_topics_query_expansion.csv')
touche_topics.head()
# Out:
#    number                                              title  \
# 0       2            Which is better, a laptop or a desktop?
# 1       3                   Which is better, Canon or Nikon?
# 2       8  What are the advantages and disadvantages of P...
# 3       9                  Why is Linux better than Windows?
# 4      12        Train or plane? Which is the better choice?
#
#                                       title_acr_full  \
# 0            Which is better, a laptop or a desktop?
# 1                   Which is better, Canon or Nikon?
# 2  What are the advantages and disadvantages of H...
# 3                  Why is Linux better than Windows?
# 4        Train or plane? Which is the better choice?
#
#                                         title_pseudo  \
# 0                  better laptop or desktop computer
# 1                              better Canon or Nikon
# 2  advantages and disadvantages PHP Python and vi...
# 3                      Linux better Windows software
# 4                Train or plane better choice travel
#
#                                           query_base  \
# 0                           better laptop or desktop
# 1                              better Canon or Nikon
# 2  advantages and disadvantages PHP Python and vi...
# 3                               Linux better Windows
# 4                       Train or plane better choice
#
#                                  query_noun  \
# 0                            laptop desktop
# 1                               Canon Nikon
# 2  advantages disadvantages PHP Python vice
# 3                             Linux Windows
# 4                        Train plane choice
#
#                                       query_synonym1  \
# 0                                good laptop desktop
# 1                                   good Canon Nikon
# 2  different advantages disadvantages PHP Python ...
# 3                                 good Linux Windows
# 4                            good Train plane choice
#
#                                     query_synonym2  \
# 0                              well laptop desktop
# 1                                 well Canon Nikon
# 2  unlike advantages disadvantages PHP Python vice
# 3                               well Linux Windows
# 4                          well Train plane choice
#
#                                       query_synonym3  \
# 0                             improve laptop desktop
# 1                                improve Canon Nikon
# 2  dissimilar advantages disadvantages PHP Python...
# 3                              improve Linux Windows
# 4                            best Train plane choice
#
#                                  query_antonym1  \
# 0                          worse laptop desktop
# 1                             worse Canon Nikon
# 2  bad advantages disadvantages PHP Python vice
# 3                           worse Linux Windows
# 4                        bad Train plane choice
#
#                                    query_antonym2
# 0                        different laptop desktop
# 1                           different Canon Nikon
# 2  worse advantages disadvantages PHP Python vice
# 3                         different Linux Windows
# 4                        worse Train plane choice

# %%
# Not relevant for the script, as you'll be getting pool of expanded from the above function.
queries = touche_topics['title']
queries_arc = touche_topics['title_acr_full']
queries_pseudo = touche_topics['title_pseudo']
base_queries = touche_topics['query_base']
noun_queries = touche_topics['query_noun']
syn1_queries = touche_topics['query_synonym1']
syn2_queries = touche_topics['query_synonym2']
syn3_queries = touche_topics['query_synonym3']
ant1_queries = touche_topics['query_antonym1']
ant2_queries = touche_topics['query_antonym2']

# %%
# Important for making the 'pyserini' library work.
# Installing linux related stuff for pyserini.
# !sudo apt-get install libomp-dev
# Installing important packages for building the new index on merged documents.
# !pip install pyserini
# !pip install faiss
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libomp5
# Suggested packages:
#   libomp-doc
# The following NEW packages will be installed:
#   libomp-dev libomp5
# 0 upgraded, 2 newly installed, 0 to remove and 42 not upgraded.
# Need to get 239 kB of archives.
# After this operation, 804 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomp5 amd64 5.0.1-1 [234 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomp-dev amd64 5.0.1-1 [5,088 B]
# Fetched 239 kB in 0s (767 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libomp5:amd64.
# (Reading database ... 155202 files and directories currently installed.)
# Preparing to unpack .../libomp5_5.0.1-1_amd64.deb ...
# Unpacking libomp5:amd64 (5.0.1-1) ...
# Selecting previously unselected package libomp-dev.
# Preparing to unpack .../libomp-dev_5.0.1-1_amd64.deb ...
# Unpacking libomp-dev (5.0.1-1) ...
# Setting up libomp5:amd64 (5.0.1-1) ...
# Setting up libomp-dev (5.0.1-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting pyserini
#   Downloading pyserini-0.16.0-py3-none-any.whl (84.6 MB)
#      |████████████████████████████████| 84.6 MB 107 kB/s
# Collecting transformers>=4.6.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 54.7 MB/s
# Collecting pyjnius>=1.4.0
#   Downloading pyjnius-1.4.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 46.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pyserini) (4.64.0)
# Collecting onnxruntime>=1.8.1
#   Downloading onnxruntime-1.11.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      |████████████████████████████████| 5.2 MB 43.0 MB/s
# Collecting spacy>=3.2.1
#   Downloading spacy-3.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 33.1 MB/s
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.3.5)
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.7/dist-packages (from pyserini) (0.29.28)
# Collecting nmslib>=2.1.1
#   Downloading nmslib-2.1.1-cp37-cp37m-manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 46.1 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.21.6)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.4.1)
# Collecting lightgbm>=3.3.2
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 33.7 MB/s
# Collecting sentencepiece>=0.1.95
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 38.8 MB/s
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.7/dist-packages (from pyserini) (1.0.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.3.2->pyserini) (0.37.1)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 46.4 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=2.1.1->pyserini) (5.4.8)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.8.1->pyserini) (2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.8.1->pyserini) (3.17.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->pyserini) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->pyserini) (2022.1)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius>=1.4.0->pyserini) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.1->pyserini) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.1->pyserini) (1.1.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (2.0.6)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.0 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (3.0.6)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (653 kB)
#      |████████████████████████████████| 653 kB 43.0 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (0.9.1)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (1.0.7)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 33.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (21.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (57.4.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 30.1 MB/s
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 6.8 MB/s
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.2.1->pyserini) (0.4.1)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.2.1->pyserini) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.2.1->pyserini) (3.0.8)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.1 MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.1->pyserini) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.1->pyserini) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.1->pyserini) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2.1->pyserini) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (3.6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (4.11.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 42.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 40.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->pyserini) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 38.4 MB/s
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3.2.1->pyserini) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.2.1->pyserini) (2.0.1)
# Installing collected packages: typing-extensions, catalogue, typer, srsly, smart-open, pyyaml, pydantic, tokenizers, thinc, spacy-loggers, spacy-legacy, sacremoses, pybind11, pathy, langcodes, huggingface-hub, transformers, spacy, sentencepiece, pyjnius, onnxruntime, nmslib, lightgbm, pyserini
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 6.0.0
#     Uninstalling smart-open-6.0.0:
#       Successfully uninstalled smart-open-6.0.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed catalogue-2.0.7 huggingface-hub-0.5.1 langcodes-3.3.0 lightgbm-3.3.2 nmslib-2.1.1 onnxruntime-1.11.1 pathy-0.6.1 pybind11-2.6.1 pydantic-1.8.2 pyjnius-1.4.1 pyserini-0.16.0 pyyaml-6.0 sacremoses-0.0.49 sentencepiece-0.1.96 smart-open-5.2.1 spacy-3.3.0 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 thinc-8.0.15 tokenizers-0.12.1 transformers-4.18.0 typer-0.4.1 typing-extensions-3.10.0.2
# Collecting faiss
#   Downloading faiss-1.5.3-cp37-cp37m-manylinux1_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from faiss) (1.21.6)
# Installing collected packages: faiss
# Successfully installed faiss-1.5.3

# %%
# Relevant for the script, loading the already stored and built index.
from pyserini.search.lucene import LuceneSearcher
searcher_opt = LuceneSearcher('/content/drive/MyDrive/touche-2022-prototyping/indexes/baseline_index')
searcher_opt.set_bm25(1.2, 0.68)

# %%
# Relevant for the script, getting the driving query retrieval in the solution dictionary.
solution_dict = {}
for id_, q_ in zip(touche_topics['number'], queries):
    hits = searcher_opt.search(q_.strip(), k=1500)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict[id_] = d_list

# %%
# Relevant for the script, getting the acronym query retrieval in the solution dictionary.
solution_dict_arc = {}
for id_, q_ in zip(touche_topics['number'], queries_arc):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_arc[id_] = d_list

# %%
# Relevant for the script, getting the driving query retrieval in the solution dictionary.
solution_dict_pseudo = {}
for id_, q_ in zip(touche_topics['number'], queries_pseudo):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_pseudo[id_] = d_list

# %%
# Relevant for the script, getting the noun query retrievals.
solution_dict_noun = {}
for id_, q_ in zip(touche_topics['number'], noun_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_noun[id_] = d_list

# %%
# Relevant for the script, getting the base query retrievals.
solution_dict_base = {}
for id_, q_ in zip(touche_topics['number'], base_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_base[id_] = d_list

# %%
# Relevant for the script, getting the syn1 query retrievals.
solution_dict_syn1 = {}
for id_, q_ in zip(touche_topics['number'], syn1_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_syn1[id_] = d_list

# %%
# Relevant for the script, getting the syn2 query retrievals.
solution_dict_syn2 = {}
for id_, q_ in zip(touche_topics['number'], syn2_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_syn2[id_] = d_list

# %%
# Relevant for the script, getting the syn3 query retrievals.
solution_dict_syn3 = {}
for id_, q_ in zip(touche_topics['number'], syn3_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_syn3[id_] = d_list

# %%
# Relevant for the script, getting the ant1 query retrievals.
solution_dict_ant1 = {}
for id_, q_ in zip(touche_topics['number'], ant1_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_ant1[id_] = d_list

# %%
# Relevant for the script, getting the ant2 query retrievals.
solution_dict_ant2 = {}
for id_, q_ in zip(touche_topics['number'], ant2_queries):
    hits = searcher_opt.search(q_.strip(), k=3000)
    d_list = []
    for h_ in hits:
        # d_= h_.docid.split('___')[0]
        d_= h_.docid
        if d_ not in d_list:
            d_list.append(d_)
    solution_dict_ant2[id_] = d_list

# %%
# IMPORTANT: Main document merging logic, you might require a function or I'll recommend straight up adding it in the voting/expansion script.
# Solution dictionary final below, will store list of all document (but not in ordered manner) to be fed into monoT5.
# The order doesn't matter as monoT5 ingnores all the associated scores.
# solution_dict_1500 = {}
solution_dict_2000 = {}
# Iterating over all the pooled queries that we have created, plus our driving query.
for (k,v), (k1,v1), (k2,v2), (k3,v3), (k4,v4), (k5,v5), (k6,v6), (k7,v7), (k8,v8), (k9,v9) \
    in zip(solution_dict.items(), solution_dict_noun.items(), solution_dict_base.items(), solution_dict_syn1.items(), \
           solution_dict_syn2.items(), solution_dict_syn3.items(), solution_dict_ant1.items(), solution_dict_ant2.items(), \
           solution_dict_arc.items(), solution_dict_pseudo.items() ):
    # Check for all k's being equal is quite unnecessary though.
    if k == k1 and k1 == k2 and k2 == k3 and k3 == k4 and k4 == k5 and k5 == k6 and k6 == k7 and k7 == k8 and k8 == k9:
        # For storing the list of 1500 relevant documents as per our merging logic.
        l_temp = []

        # Finding commonality amongst documents from different queries.
        # Below 'v' represents documents from driving main query.
        # We essentially check, whether the given document v_ in v is present
        # in any of the other retrievals by other pool of expanded queries.
        # If, v_ is present in any of the documents we add it into the l_temp.
        v_x = v[:1000] # Limiting only to 1000 common entries only.
        for v_ in v_x:
            c_b = 0
            if v_ in v1:
                c_b = c_b + 1
            if v_ in v2:
                c_b = c_b + 1
            if v_ in v3:
                c_b = c_b + 1
            if v_ in v4:
                c_b = c_b + 1
            if v_ in v5:
                c_b = c_b + 1
            if c_b >= 1:
                l_temp.append(v_)

        # For the query we will append documents
        # till it reaches the 1125 document count for l_temp.
        diff_ = 1050 - len(l_temp)

        # Appending document logic.
        c_ = 0
        for vx_ in v8: # Appending acronym query documents.
            if vx_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(vx_)
            elif c_ > diff_:
                break
            c_ = c_ + 1

        # Appending document logic.
        c_ = 0
        for v1_ in v1: # Appending base query documents.
            if v1_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v1_)
            elif c_ > 125:
                break
            c_ = c_ + 1

        c_ = 0
        for v2_ in v2: # Appending noun query documents.
            if v2_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v2_)
            elif c_ > 125:
                break
            c_ = c_ + 1

        c_ = 0
        for v3_ in v3: # Appending syn1 documents.
            if v3_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v3_)
            elif c_ > 35:
                break
            c_ = c_ + 1

        c_ = 0
        for v4_ in v4: # Appending syn2 documents.
            if v4_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v4_)
            elif c_ > 34:
                break
            c_ = c_ + 1

        c_ = 0
        for v5_ in v5: # Appending syn3 documents.
            if v5_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v5_)
            elif c_ > 33:
                break
            c_ = c_ + 1

        c_ = 0
        for v6_ in v6: # Appending ant documents.
            if v6_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v6_)
            elif c_ > 25:
                break
            c_ = c_ + 1

        c_ = 0
        for v7_ in v7: # Appending ant documents.
            if v7_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v7_)
            elif c_ > 25:
                break
            c_ = c_ + 1
        
        c_ = 0
        for v8_ in v: # Appending org. documents.
            if v8_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v8_)
            elif c_ > 175:
                break
            c_ = c_ + 1

        for v9_ in v9: # Appending pseudo relevance documents.
            if v9_ not in l_temp: # Only relevant non-existing docs added.
                l_temp.append(v9_)

        # solution_dict_1500[k] = l_temp[:1500]
        solution_dict_2000[k] = l_temp[:2000]

# %%
# Storing values present in dictionaries.
# ids_1500 = []
ids_2000 = []
# res_1500 = []
res_2000 = []
# for x, y in solution_dict_1500.items():
#     ids_1500.append(x)
#     res_1500.append(y)

for x, y in solution_dict_2000.items():
    ids_2000.append(x)
    res_2000.append(y)

# print(set(ids_1500) == set(ids_2000))
# print(len(ids_1500), len(res_1500), len(res_1500[1]))
print(len(ids_2000), len(res_2000), len(res_2000[1]))
# Out:
# 50 50 2000

# %%
# Storing the final results in pandas csv form and jsonlines form for the retrieval.
# query1500_df = pd.DataFrame({'query_id': ids_1500,'query':queries,'document_ids': res_1500})
query2000_df = pd.DataFrame({'query_id': ids_2000,'query':queries,'document_ids': res_2000})

# %%
# query1500_df.head()

# %%
query2000_df.head()
# Out:
#    query_id                                              query  \
# 0         2            Which is better, a laptop or a desktop?
# 1         3                   Which is better, Canon or Nikon?
# 2         8  What are the advantages and disadvantages of P...
# 3         9                  Why is Linux better than Windows?
# 4        12        Train or plane? Which is the better choice?
#
#                                         document_ids
# 0  [clueweb12-0608wb-66-03868___1, clueweb12-0001...
# 1  [clueweb12-0405wb-11-27558___46, clueweb12-110...
# 2  [clueweb12-0008wb-36-19669___42, clueweb12-180...
# 3  [clueweb12-0608wb-30-15417___40, clueweb12-060...
# 4  [clueweb12-1204wb-20-15853___8, clueweb12-1019...

# %%
# Saving dataframes as csv files.
# query1500_df.to_csv('drive/MyDrive/touche-2022-prototyping/topics-task2-2022/initial-retrieval-1500.csv', encoding='utf-8', index=False)
query2000_df.to_csv('drive/MyDrive/touche-2022-prototyping/topics-task2-2022/pseudo-initial-retrieval-2000.csv', encoding='utf-8', index=False)

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-3.0.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonlines) (3.10.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from jsonlines) (21.4.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-3.0.0

# %%
# Writing the above dataframes in jsonline files.
# output1500 = jsonlines.open('drive/MyDrive/touche-2022-prototyping/topics-task2-2022/retrieval-1500.jsonl', 'w')
output2000 = jsonlines.open('drive/MyDrive/touche-2022-prototyping/topics-task2-2022/pseudo-retrieval-2000.jsonl', 'w')

# for x, q, y in zip(query1500_df['query_id'], queries, query1500_df['document_ids']):
#     output1500.write({
#             'query_id': x,
#             'query': q,
#             'document_ids': y
#         })

for x, q, y in zip(query2000_df['query_id'], queries, query2000_df['document_ids']):
    output2000.write({
            'query_id': x,
            'query': q,
            'document_ids': y
        })

# %%
# Creating file as input for the monoT5 model.
# Loading the dataframe files of the saved results from the 
# query1500_df = pd.read_csv('/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/initial-retrieval-1500.csv')
# print(query1500_df.head())
query2000_df = pd.read_csv('/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/pseudo-initial-retrieval-2000.csv')
print(query2000_df.head())
# Out:
#    query_id                                              query  \
# 0         2            Which is better, a laptop or a desktop?
# 1         3                   Which is better, Canon or Nikon?
# 2         8  What are the advantages and disadvantages of P...
# 3         9                  Why is Linux better than Windows?
# 4        12        Train or plane? Which is the better choice?
#
#                                         document_ids
# 0  ['clueweb12-0608wb-66-03868___1', 'clueweb12-0...
# 1  ['clueweb12-0405wb-11-27558___46', 'clueweb12-...
# 2  ['clueweb12-0008wb-36-19669___42', 'clueweb12-...
# 3  ['clueweb12-0608wb-30-15417___40', 'clueweb12-...
# 4  ['clueweb12-1204wb-20-15853___8', 'clueweb12-1...

# %%
# Storing the input file results from the monoT5 model into list
# for dataframe conversion.
# input_1500 = []
input_2000 = []

# %%
# Installing jsonlines library.
# !pip install jsonlines
import jsonlines
# Out:
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.7/dist-packages (3.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from jsonlines) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonlines) (3.10.0.2)

# %%
# Loading the document corpus for getting document content and processing it.
qcorpus_list = list(jsonlines.open('/content/drive/MyDrive/touche-2022-prototyping/touche-task2-passages-version-002-expanded-with-doc-t5-query.jsonl'))

# %%
# NLTK related import statements.
# import statements, must required for the final script.
# All the document processing related import statements.
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Creating an input file for indexing with preprocessing in the pyserini compatible format.
doc_dictionary = {}
# Loading all the stop words frome english language.
# stop_words = set(stopwords.words("english"))
for vals in tqdm(qcorpus_list):
    document = vals['contents']
    document = document.lower()
    # Remove punctuation and numbers.
    document = re.sub(r"[^A-Za-z\s]+", " ", document)
    # Remove extra XML query tag.
    document = document.replace("query"," ")
    # Remove extra white spaces.
    document = re.sub(r"[\s]{2,}", " ", document)
    # Tokenize string.
    # word_tokens = word_tokenize(document)
    # Remove stop words.
    # word_tokens = [token for token in word_tokens if token not in stop_words]
    # word_tokens = [token for token in word_tokens if len(token) > 1]
    # Combining word tokens for results.
    results = document
    document = results.strip()
    doc_dictionary[vals['id']] = document
# Out:
# 100%|██████████| 868655/868655 [01:15<00:00, 11577.16it/s]

# %%
# For converting string representation of list into actual lists.
import ast

# %%
def query_basic_preprocess(input_query):
    input_query = input_query.lower()
    # Remove punctuation and numbers.
    input_query = re.sub(r"[^A-Za-z\s]+", " ", input_query)
    # Remove extra white spaces.
    input_query = re.sub(r"[\s]{2,}", " ", input_query)
    # Tokenize string.
    # word_tokens = word_tokenize(input_query)
    # Remove stop words.
    # word_tokens = [token for token in word_tokens if token not in stop_words]
    # word_tokens = [token for token in word_tokens if len(token) > 1]
    # Combining word tokens for results.
    # results = " ".join(word_tokens)
    output_query = input_query.strip()
    return output_query

# %%
# apply basic preprocessing to the input queries.
query2000_df['query'] = query2000_df['query'].apply(lambda x: query_basic_preprocess(x))

# %%
for ti_, q_, doc_list in zip(query2000_df['query_id'], query2000_df['query'], query2000_df['document_ids']):
    doc_list = ast.literal_eval(doc_list)
    doc_list = [n.strip() for n in doc_list]
    for doc_ in doc_list:
        input_2000.append({"title_id":ti_,"title":q_,'doc_id': doc_,"content": doc_dictionary[doc_]})

# %%
input_2000[:10]
# Out:
# [{'content': 'desktop or laptop what the tech homeforumscontact hijackthissearchhelp please visit our forums for help with malware removal or any tech support question take me to the forums desktop or laptop aug posted by hemal in hardware do i buy a laptop or a desktop computer for my next machine i am not sure if laptops are just replacing desktops and if i should just not waste my money on a desktop or if they are still better computers thanks laptops are becoming more prevalent in the tech world today becoming the staple of computing especially on the college scene desktops the office work horse are slowly becoming edged out of the picture due to their lack of portability but are they being underrated if you re considering buying either a new desktop or laptop you have to view the pros and cons of both and whether which would serve you better let s outline a few do you need a laptop or desktop',
#   'doc_id': 'clueweb12-0608wb-66-03868___1',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'desktop replacements are usually larger and heavier than standard laptops they contain more powerful components and have a or larger display they are bulkier and not as portable as other laptops and their operation time on batteries is typically shorter they are intended to be used as compact and transportable alternatives to a desktop computer some laptops in this class use a limited range of desktop components to provide better performance for the same price at the expense of battery life a few of those models have no battery in the early s desktops were more powerful easier to upgrade and much cheaper than laptops but in later years laptops have become much cheaper and more powerful and most peripherals are available in laptop compatible usb versions which minimise the need for internal add on cards in the second half of laptops outsold desktops for the first time why are laptops better than desktops',
#   'doc_id': 'clueweb12-0001wb-72-30848___8',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'there has been a turnaround in pricing trends over the past few months whereas laptops were marginally higher priced than a desktop computer some manufacturers are putting very economically priced laptops on the market they may not have all the features that the more expensive laptops and desktop versions have but they are never the less good value for money the desktop the desktop computer is obviously less portable than a laptop however if you want a personal computer that will perform better then a desktop will be your best option if you want a computer for tasks such as video and photo editing and even gaming then a desktop will be able to hold more of the requirements than a laptop when it comes to repairs a desktop computer is more economical to run and repair than a laptop desktops are also more robust than laptops what is the difference between a laptop and a desktop computer',
#   'doc_id': 'clueweb12-0907wb-60-03588___2',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'therefore hard drives in a laptop usually have relatively smaller storage capacities than their desktop counterparts so if you need a computer for data storage it is advisable to go for a desktop if you need a computer for research for taking notes or for any other purpose that demands mobility buying a laptop will be the better choice not only a laptop is movable but it can also work on battery power giving you the freedom to work wherever you want if your work involves graphic editing animations designing etc choosing a desktop is advisable because of the larger screen sizes and flexibility of desktop monitors with a laptop you get all the peripherals built into the machine which need to be separately bought in case of a desktop this may be either good or bad depending upon your choice of peripherals and budget why is it better to buy a laptop or desktop',
#   'doc_id': 'clueweb12-1804wb-90-15876___2',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'do you like laptops or desktops better mister poll welcome sign in to access your account new user create new account safe mode on home directory search random poll make a poll do you like laptops or desktops better results messages laptops desktops this poll was created on by dannyboy faq privacy info contact us about us find us on facebook copyright pollbob inc all rights reserved mister poll and the mister poll logo are trademarks of pollbob inc all content and information is presented for entertainment purposes only there was a problem processing your data please try again do you like laptops or desktops better',
#   'doc_id': 'clueweb12-0601wb-28-19879___1',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'laptop computers are portable have the virtual no cord image and can travel with you they are becoming very light increasingly more powerful and have better features as the days go on desktop computers are the ultimate powerhouse out perform laptops and are much cheaper with the ability to upgrade making them less obsolete and preserving your investment longer the user for a laptop should be purchasing the laptop because they want to carry it around with them and be mobile with their computing they should not care too much about battery life and be willing to spend more money to purchase less a desktop user should be looking for a more high end type of computer but lack of portability the desktop user may have a limited budget but will have the ability to continually upgrade the desktop over time to continue to preserve its longevity and life in an increasingly growing industry why is a desktop computer better than a laptop',
#   'doc_id': 'clueweb12-0608wb-66-03868___2',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'dmacfour pm hide with you could get a laptop with a much better video card will get you one with an m gts hawler pm hide i think the desktop in this article was bought not built that would account for the bad price performance it shows i guess that would make sense a comparison of what you can go to the store and buy then again i know i ll never be buying a desktop from a store but i also know that if i want power i should build a desktop to get about twice the performance or more for my money fabarati pm hide both the notebook and desktops were bad choices you can definitly find better priced laptops desktops for the same price or better specified configurations for that price what is the best price for a laptop',
#   'doc_id': 'clueweb12-0603wb-91-13413___10',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'gateway s nv s u is more affordable offers more memory and ram and has better integrated graphics but no blu ray drive finally themsi fr offers a faster i quad core processor and more ram but lacks the blu ray support overall each of these options is just a bit better than sony s depending upon the needs of the consumer buy direct user reviews write a review be the first to write a review related guide picks best desktop replacements best budget laptops best thin light laptops best ultraportable laptops best netbooks related resources laptop pc buyer s guide how to get a pc for less common pc buyer mistakes sony support profile related articles sony vaio vpc ec fx bi inch desktop replacement laptop personal compu sony vaio vpc ef fx bi inch desktop replacement laptop personal compu sony vaio vgn aw j b inch entertainment desktop replacement laptop p sony vaio vgn sr inch ultraportable laptop personal computer review sony vaio vgn aw j h inch desktop replacement laptop personal comput which laptop is better',
#   'doc_id': 'clueweb12-0006wb-17-30732___8',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'what about ergonomics early laptops had cramped keyboards and small dimly lit hard to read screens nowadays most of these issues have been resolved but for certain users desktops still may be the better choice to help prevent injuries and discomfort because a desktop s monitor and keyboard are separate you can move and adjust them as needed and desktop monitors can be purchased in much larger sizes than what is available on a laptop a laptop s setup with an attached keyboard and monitor provides less flexibility it is however possible to set a laptop up in a way that s ergonomically similar to a desktop with an additional keyboard and monitor but the extra equipment required might negate the entire purpose of having a laptop bookmark email this hits comments subscribe to this comment s feed write comment email name website comment smaller bigger subscribe via email registered users only i have read and agree to theterms of usage why is a laptop better than a desktop',
#   'doc_id': 'clueweb12-1412wb-03-18627___5',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2},
#  {'content': 'many times consumers may opt to have both but for many this is not an affordable option and in reality is unnecessary while desktops are more practical for home laptops are mobile so you can actually get the best of both worlds when deciding on laptop versus desktop here are some considerations and five reasons why a laptop maybe a better choice mobility the number one argument for laptops is of course mobility and portability laptops offer full computer capabilities without the hassle of a plug they can be used at the beach as well as at home at your workstation desk or couch while watching tv you certainly could not do that with a desktop and because today s laptops offer full and powerful features they can actually serve as replacement laptops such as several dell computers models the other advantage is the ability to surf the web to shop or check email from anywhere which can be especially beneficial for work and business or to just communicate with friends and family why is a laptop better than a desktop',
#   'doc_id': 'clueweb12-0301wb-84-10147___2',
#   'title': 'which is better a laptop or a desktop',
#   'title_id': 2}]

# %%
# for ti_, q_, doc_list in zip(query1500_df['query_id'], query1500_df['query'], query1500_df['document_ids']):
#     doc_list = ast.literal_eval(doc_list)
#     doc_list = [n.strip() for n in doc_list]
#     for doc_ in doc_list:
#         input_1500.append({"title_id":ti_,"title":q_,'doc_id': doc_,"content": doc_dictionary[doc_]})

# %%
# input_1500[:10]

# %%
# input_1500_df=pd.DataFrame(input_1500)
# print(input_1500_df.head())

# %%
# input_1500_df.to_csv("/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/monoT5-input-1500.csv", index=False)

# %%
input_2000_df=pd.DataFrame(input_2000)
print(input_2000_df.head())
# Out:
#    title_id                                  title  \
# 0         2  which is better a laptop or a desktop
# 1         2  which is better a laptop or a desktop
# 2         2  which is better a laptop or a desktop
# 3         2  which is better a laptop or a desktop
# 4         2  which is better a laptop or a desktop
#
#                           doc_id  \
# 0  clueweb12-0608wb-66-03868___1
# 1  clueweb12-0001wb-72-30848___8
# 2  clueweb12-0907wb-60-03588___2
# 3  clueweb12-1804wb-90-15876___2
# 4  clueweb12-0601wb-28-19879___1
#
#                                              content
# 0  desktop or laptop what the tech homeforumscont...
# 1  desktop replacements are usually larger and he...
# 2  there has been a turnaround in pricing trends ...
# 3  therefore hard drives in a laptop usually have...
# 4  do you like laptops or desktops better mister ...

# %%
input_2000_df.to_csv("/content/drive/MyDrive/touche-2022-prototyping/topics-task2-2022/pseudo-monoT5-input-2000.csv", index=False)
