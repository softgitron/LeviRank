# %%
# Relevant Reference Links for Stance Prediction
# For Queries q and Documents d at hand.
# Baseline Code: https://github.com/dh1105/Sentence-Entailment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# execute once: Removing the extra directory.
# !rm -r sample_data/

# %%
# loading the stance prediction dataset tsv file.
import pandas as pd
stance_df = pd.read_csv('/content/drive/MyDrive/touche-2022-prototyping/touche22-task2-stance-dataset.tsv', sep='\t')

# %%
print(set(stance_df.ds))
# Out:
# {'softwareengineering.stackexchange', 'yahoo', 'travel.stackexchange', 'cooking.stackexchange', 'superuser.stackexchange', 'softwarerecs.stackexchange', 'gardening.stackexchange', 'academia.stackexchange', 'music.stackexchange', 'cs.stackexchange'}

# %%
stance_df.head()
# Out:
#                                   ds     id  \
# 0  softwareengineering.stackexchange  10373
# 1  softwareengineering.stackexchange  18838
# 2  softwareengineering.stackexchange  19392
# 3  softwareengineering.stackexchange  20653
# 4  softwareengineering.stackexchange  21186
#
#                                             question  \
# 0  What's the better way to charge for a cloud pl...
# 1               Haskell AND Lisp vs. Haskell OR Lisp
# 2  When is it better to offload work to the RDBMS...
# 3  Is it better to specialize in a single field I...
# 4  Microsoft SDE Interview vs Microsoft SDET Inte...
#
#                                               answer  answer_stance  \
# 0  Like all good questions, the answer depends. I...              2
# 1  I suggest learning both, Haskell first, then C...              2
# 2  You want to do all set-based operations in the...              3
# 3  Specialise if you enjoy it  As you are aware, ...              3
# 4  Unfortunately, those are both myths. SDEs and ...              1
#
#                               answer_stance_object  object_count  \
# 0                        simple but more expensive             2
# 1                                 Haskell AND Lisp             2
# 2                                    do it in code             2
# 3  expand into other fields to broaden my horizons             2
# 4                                          Neutral             2
#
#                                  object_1  \
# 0               simple but more expensive
# 1                        Haskell AND Lisp
# 2               offload work to the RDBMS
# 3  to specialize in a single field I like
# 4                 Microsoft SDE Interview
#
#                                          mask_pos_1  \
# 0  [[231, 252], [389, 393], [605, 619], [753, 757]]
# 1                                        [[25, 56]]
# 2                            [[40, 55], [232, 248]]
# 3                [[53, 63], [404, 410], [512, 519]]
# 4                [[37, 41], [283, 295], [950, 962]]
#
#                                           object_2  \
# 0                          complicated but cheaper
# 1                                  Haskell OR Lisp
# 2                                    do it in code
# 3  expand into other fields to broaden my horizons
# 4                         Microsoft SDET Interview
#
#                                        mask_pos_2
# 0                                              []
# 1                                              []
# 2                        [[165, 175], [578, 598]]
# 3                                    [[892, 933]]
# 4  [[46, 51], [341, 354], [832, 836], [938, 945]]

# %%
stance_df[stance_df.ds.isin(['yahoo'])]
# Removing 'yahoo' data source from the analysis.
# Out:
#         ds       id question   answer  answer_stance  \
# 35   yahoo  1020731  1020731  1020731              3
# 36   yahoo  1067597  1067597  1067597              3
# 37   yahoo   120337   120337   120337              3
# 38   yahoo  1205525  1205525  1205525              1
# 39   yahoo  1211167  1211167  1211167              2
# ..     ...      ...      ...      ...            ...
# 951  yahoo  4268101  4268101  4268101              2
# 952  yahoo  4369635  4369635  4369635              1
# 953  yahoo  4413933  4413933  4413933              2
# 954  yahoo   618287   618287   618287              3
# 955  yahoo   928164   928164   928164              1
#
#            answer_stance_object  object_count                    object_1  \
# 35                       Accord             2                       Camry
# 36           LCD big screen tvs             2                     plasmaq
# 37                     charcoal             2                         gas
# 38                      Neutral             2                     windows
# 39                          BMW             2                         BMW
# ..                          ...           ...                         ...
# 951  free downloadable browsers             2  free downloadable browsers
# 952                     Neutral             2           second hand smoke
# 953                        Rock             2                        Rock
# 954                     Ang Lee             2                   Tsui Hark
# 955                     Neutral             2              ashlee simpson
#
#                                             mask_pos_1            object_2  \
# 35                             [[95, 100], [347, 352]]              Accord
# 36                                          [[47, 54]]  LCD big screen tvs
# 37   [[66, 76], [168, 171], [1062, 1065], [1083, 10...            charcoal
# 38      [[78, 85], [181, 188], [194, 201], [950, 957]]               linux
# 39   [[174, 183], [249, 252], [441, 444], [493, 498...        infinity G35
# ..                                                 ...                 ...
# 951     [[73, 80], [227, 234], [480, 487], [739, 746]]   Internet Explorer
# 952                                       [[149, 166]]          first hand
# 953                 [[10, 14], [472, 476], [500, 504]]                 Rap
# 954                                                 []             Ang Lee
# 955                                                 []        paris hilton
#
#                                             mask_pos_2
# 35   [[4, 10], [29, 35], [221, 227], [358, 364], [4...
# 36                                                  []
# 37   [[6, 14], [53, 61], [80, 88], [212, 227], [259...
# 38                [[359, 364], [685, 690], [876, 881]]
# 39   [[146, 165], [230, 238], [348, 356], [768, 780...
# ..                                                 ...
# 951                                       [[775, 777]]
# 952                                                 []
# 953                             [[23, 34], [572, 575]]
# 954                                          [[9, 16]]
# 955                                                 []
#
# [511 rows x 11 columns]

# %%
stance_df = stance_df[stance_df.ds.isin(['cs.stackexchange', 'superuser.stackexchange',
                                         'travel.stackexchange', 'gardening.stackexchange',
                                         'softwareengineering.stackexchange', 'softwarerecs.stackexchange',
                                         'music.stackexchange', 'academia.stackexchange', 'cooking.stackexchange'])]

# %%
print(set(stance_df.ds))
stance_df.head()
# Out:
# {'softwareengineering.stackexchange', 'travel.stackexchange', 'cooking.stackexchange', 'superuser.stackexchange', 'softwarerecs.stackexchange', 'gardening.stackexchange', 'academia.stackexchange', 'music.stackexchange', 'cs.stackexchange'}
#                                   ds     id  \
# 0  softwareengineering.stackexchange  10373
# 1  softwareengineering.stackexchange  18838
# 2  softwareengineering.stackexchange  19392
# 3  softwareengineering.stackexchange  20653
# 4  softwareengineering.stackexchange  21186
#
#                                             question  \
# 0  What's the better way to charge for a cloud pl...
# 1               Haskell AND Lisp vs. Haskell OR Lisp
# 2  When is it better to offload work to the RDBMS...
# 3  Is it better to specialize in a single field I...
# 4  Microsoft SDE Interview vs Microsoft SDET Inte...
#
#                                               answer  answer_stance  \
# 0  Like all good questions, the answer depends. I...              2
# 1  I suggest learning both, Haskell first, then C...              2
# 2  You want to do all set-based operations in the...              3
# 3  Specialise if you enjoy it  As you are aware, ...              3
# 4  Unfortunately, those are both myths. SDEs and ...              1
#
#                               answer_stance_object  object_count  \
# 0                        simple but more expensive             2
# 1                                 Haskell AND Lisp             2
# 2                                    do it in code             2
# 3  expand into other fields to broaden my horizons             2
# 4                                          Neutral             2
#
#                                  object_1  \
# 0               simple but more expensive
# 1                        Haskell AND Lisp
# 2               offload work to the RDBMS
# 3  to specialize in a single field I like
# 4                 Microsoft SDE Interview
#
#                                          mask_pos_1  \
# 0  [[231, 252], [389, 393], [605, 619], [753, 757]]
# 1                                        [[25, 56]]
# 2                            [[40, 55], [232, 248]]
# 3                [[53, 63], [404, 410], [512, 519]]
# 4                [[37, 41], [283, 295], [950, 962]]
#
#                                           object_2  \
# 0                          complicated but cheaper
# 1                                  Haskell OR Lisp
# 2                                    do it in code
# 3  expand into other fields to broaden my horizons
# 4                         Microsoft SDET Interview
#
#                                        mask_pos_2
# 0                                              []
# 1                                              []
# 2                        [[165, 175], [578, 598]]
# 3                                    [[892, 933]]
# 4  [[46, 51], [341, 354], [832, 836], [938, 945]]

# %%
from sklearn.utils import shuffle
dataset_df = shuffle(stance_df[['question','answer','answer_stance']])
dataset_df.head()
# Out:
#                                               question  \
# 163  Is it better to pick herbs from the top or bot...
# 107  What are some of the benefits of electric stov...
# 589  Ferrying Icelandic rental car vs renting on Fa...
# 818  Should I be a visiting student rather than a n...
# 513  Windows Phone 7 dev: C# or silverlight for a s...
#
#                                                 answer  answer_stance
# 163  I would take basil by pinching whole stems off...              0
# 107  Can I convince you that electric is better? No...              3
# 589  Although all comments were helpful it seems th...              1
# 818  Enrolling as a non-degree-seeking graduate stu...              2
# 513  Ok, you're confusing technologies.    C# is a ...              0

# %%
print(dataset_df.shape)
train_df = dataset_df[:380]
# val_df = dataset_df[335:380]
val_df = dataset_df[380:]
print(train_df.shape)
print(val_df.shape)
# print(test_df.shape)
# Out:
# (445, 3)
# (380, 3)
# (65, 3)

# %%
train_df.head(5)
# Out:
#                                               question  \
# 163  Is it better to pick herbs from the top or bot...
# 107  What are some of the benefits of electric stov...
# 589  Ferrying Icelandic rental car vs renting on Fa...
# 818  Should I be a visiting student rather than a n...
# 513  Windows Phone 7 dev: C# or silverlight for a s...
#
#                                                 answer  answer_stance
# 163  I would take basil by pinching whole stems off...              0
# 107  Can I convince you that electric is better? No...              3
# 589  Although all comments were helpful it seems th...              1
# 818  Enrolling as a non-degree-seeking graduate stu...              2
# 513  Ok, you're confusing technologies.    C# is a ...              0

# %%
# execute once only, then only it will work correctly.
def replace_labels(val):
    if val == 0:
        return 'NO'
    elif val == 1: 
        return 'NEUTRAL'
    else:
        return 'OBJECT' # Second stance prediction model, classify 'FIRST' & 'SECOND'

# %%
# apply the replace_labels function in all the dataframe values.
train_df['answer_stance'] = train_df['answer_stance'].apply(lambda x : replace_labels(x))
val_df['answer_stance'] = val_df['answer_stance'].apply(lambda x : replace_labels(x))
# test_df['answer_stance'] = test_df['answer_stance'].apply(lambda x : replace_labels(x))
train_df['answer_stance'] = train_df['answer_stance'].astype(str)
val_df['answer_stance'] = val_df['answer_stance'].astype(str)
# test_df['answer_stance'] = test_df['answer_stance'].astype(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
val_df.head(20)
# Out:
#                                               question  \
# 153  Is Clopyralid or Dicamba more effective in the...
# 791  Which is preferable, to go to graduate school ...
# 530              Wireless PCI Card vs Wireless Bridge?
# 34   Is it better to blindly match the project requ...
# 69                     Ph.D. adviser or Ph.D. advisor?
# 185  Why Firefox on Linux looks different than Wind...
# 545  Noticeable difference between i7 920 and 940 p...
# 200  Should I book Thailand Rail tickets online (pr...
# 569  Which Shanghai airport is convenient for city ...
# 157  What are the pros and cons of bagged mulch ver...
# 904            Writing robust code vs. overengineering
# 931  How to better start learning programming - wit...
# 458          Ceramic vs Stainless Steel in coffee mugs
# 10   What's the better user experience: Waiting onc...
# 830  Is it better to focus on relearning mathematic...
# 807  What is the difference between a teaching assi...
# 500  What do you look at first: the code or the des...
# 553     What is the difference between Unix and Linux?
# 802  Should those more interested in research choos...
# 196  Car rental vs. buying a car for 1 month, when ...
#
#                                                 answer answer_stance
# 153  It depends to some extent what you mean by 'cl...       NEUTRAL
# 791    I've heard from people that generally, it's ...        OBJECT
# 530  I purchased a wireless bridge for my desktop i...        OBJECT
# 34   It is better to explain what the customer will...        OBJECT
# 69   According to the New Oxford American Dictionar...        OBJECT
# 185  Apparently, it's because Linux users want it t...       NEUTRAL
# 545  "don't bother, not worth the extra cash".  If ...       NEUTRAL
# 200  I have not used that web site, but always boug...       NEUTRAL
# 569  With the help of Google maps, using the public...        OBJECT
# 157  Dark color is not necessarily a sign of health...        OBJECT
# 904    How do you guys know that you are writing th...        OBJECT
# 931  I used to teach Prolog as a first language to ...       NEUTRAL
# 458  Stainless Steel  Most stainless steel travel m...        OBJECT
# 10   Startup as fast as possible, use a thread to d...        OBJECT
# 830  Why not both?   If you aren't explicitly a mat...       NEUTRAL
# 807  No, there really is no universal definition of...       NEUTRAL
# 500  I start with code. Separate design documents, ...        OBJECT
# 553  Unix isn't one thing, it's a name for a large ...            NO
# 802  In my discipline, mathematics, there is a huge...       NEUTRAL
# 196  Buying option  For a one-month trip, I do not ...        OBJECT

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 8.2 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 52.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 66.1 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 62.4 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0

# %%
# !pip install jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-3.0.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonlines) (4.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from jsonlines) (21.4.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-3.0.0

# %%
import torch
import jsonlines
import random
import os
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification, get_cosine_schedule_with_warmup
from tqdm import tqdm
from typing import List
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device "{device}"')
batch_size = 1
gpu_batch = 1
# Out:
# Using device "cuda"

# %%
class LabelPredictionDataset(Dataset):
    def __init__(self, dataset_df):
        self.samples = []
        label_encodings = {'NO': 0, 'NEUTRAL': 1, 'OBJECT': 2}

        for q_, a_, l_ in zip(dataset_df['question'],dataset_df['answer'],dataset_df['answer_stance']):
            self.samples.append({
                'claim': q_,
                'rationale': a_,
                'label': label_encodings[l_]
            })


    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx]

def encode(claim: List[str], rationale: List[str]):
    encoding = tokenizer(claim, rationale, padding=True, truncation=True, max_length=512, return_tensors="pt")
    input_ids = encoding['input_ids']
    attention_mask = encoding['attention_mask']
    return input_ids, attention_mask

def evaluate(model, dataset):
    model.eval()
    targets = []
    outputs = []
    with torch.no_grad():
        for batch in DataLoader(dataset, batch_size=gpu_batch):
            input_ids, attention_mask = encode(batch['claim'], batch['rationale'])
            logits = model(input_ids.to(device)).logits
            targets.extend(batch['label'].float().tolist())
            outputs.extend(logits.argmax(dim=1).tolist())
    return {
        'macro_f1': f1_score(targets, outputs, zero_division=0, average='macro'),
        'f1': tuple(f1_score(targets, outputs, zero_division=0, average=None)),
        'precision': tuple(precision_score(targets, outputs, zero_division=0, average=None)),
        'recall': tuple(recall_score(targets, outputs, zero_division=0, average=None))
    }

# %%
trainset = LabelPredictionDataset(train_df)
devset = LabelPredictionDataset(val_df)

# %%
tokenizer = AutoTokenizer.from_pretrained("roberta-large-mnli")
model = AutoModelForSequenceClassification.from_pretrained("roberta-large-mnli").to(device)
# Out:
# Downloading:   0%|          | 0.00/688 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
optimizer = torch.optim.Adam([
            {'params': model.roberta.parameters(), 'lr': 5e-5},
            {'params': model.classifier.parameters(), 'lr': 1e-4}
        ])
scheduler = get_cosine_schedule_with_warmup(optimizer, 128, 50 * 1)

# %%
# !mkdir /content/drive/MyDrive/touche-2022-prototyping/saved_models
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/touche-2022-prototyping/saved_models’: File exists

# %%
model_path = '/content/drive/MyDrive/touche-2022-prototyping/saved_models'

# %%
for e in range(5): # epoch count has to be changed for ideal performance.
    model.train()
    t = tqdm(DataLoader(trainset, batch_size=1, shuffle=True))
    for i, batch in enumerate(t):
        input_ids, attention_mask = encode(batch['claim'], batch['rationale'])
        outputs = model(input_ids=input_ids.to(device), attention_mask=attention_mask.to(device), labels=batch['label'].long().to(device))
        loss = outputs.loss
        loss.backward()
        if (i + 1) % (1 // 1) == 0:
            optimizer.step()
            optimizer.zero_grad()
            t.set_description(f'Epoch {e}, iter {i}, loss: {round(loss.item(), 4)}')
    scheduler.step()
    checkpoint = {
        'epoch': e + 1,
        'optimizer': optimizer.state_dict()
    }
    # Eval
    train_score = evaluate(model, trainset)
    print(f'Epoch {e} train score:')
    print(train_score)
    dev_score = evaluate(model, devset)
    print(f'Epoch {e} dev score:')
    print(dev_score)

    # Save
    # add model_path for saving the ideal model and save it in separate block execution.
    save_path = os.path.join('./saved_models', f'support_classifier-epoch-{e}-f1-{int(dev_score["macro_f1"] * 1e4)}') 
    os.makedirs(save_path)
    tokenizer.save_pretrained(save_path)
    model.save_pretrained(save_path)
# Out:
# Epoch 0, iter 379, loss: 1.8692: 100%|██████████| 380/380 [01:56<00:00,  3.26it/s]
# Epoch 0 train score:
# {'macro_f1': 0.2121767994409504, 'f1': (0.125, 0.5115303983228512, 0.0), 'precision': (0.11904761904761904, 0.3620178041543027, 0.0), 'recall': (0.13157894736842105, 0.8714285714285714, 0.0)}
# Epoch 0 dev score:
# {'macro_f1': 0.19157088122605362, 'f1': (0.0, 0.5747126436781609, 0.0), 'precision': (0.0, 0.4166666666666667, 0.0), 'recall': (0.0, 0.9259259259259259, 0.0)}
# Epoch 1, iter 379, loss: 0.7258: 100%|██████████| 380/380 [02:00<00:00,  3.15it/s]
# Epoch 1 train score:
# {'macro_f1': 0.3851339423628581, 'f1': (0.17857142857142858, 0.3614457831325302, 0.6153846153846154), 'precision': (0.2777777777777778, 0.41284403669724773, 0.5533596837944664), 'recall': (0.13157894736842105, 0.32142857142857145, 0.693069306930693)}
# Epoch 1 dev score:
# {'macro_f1': 0.3324675324675325, 'f1': (0.0, 0.39999999999999997, 0.5974025974025975), 'precision': (0.0, 0.43478260869565216, 0.5609756097560976), 'recall': (0.0, 0.37037037037037035, 0.6388888888888888)}
# Epoch 2, iter 379, loss: 1.3391: 100%|██████████| 380/380 [02:01<00:00,  3.14it/s]
# Epoch 2 train score:
# {'macro_f1': 0.3475313156344482, 'f1': (0.18604651162790697, 0.15853658536585366, 0.698010849909584), 'precision': (0.8, 0.5416666666666666, 0.5498575498575499), 'recall': (0.10526315789473684, 0.09285714285714286, 0.9554455445544554)}
# Epoch 2 dev score:
# {'macro_f1': 0.23774587985114307, 'f1': (0.0, 0.06060606060606061, 0.6526315789473686), 'precision': (0.0, 0.16666666666666666, 0.5254237288135594), 'recall': (0.0, 0.037037037037037035, 0.8611111111111112)}
# Epoch 3, iter 379, loss: 0.9099: 100%|██████████| 380/380 [02:02<00:00,  3.11it/s]
# Epoch 3 train score:
# {'macro_f1': 0.5438465620836441, 'f1': (0.38297872340425526, 0.5306122448979592, 0.7179487179487178), 'precision': (1.0, 0.6190476190476191, 0.631578947368421), 'recall': (0.23684210526315788, 0.4642857142857143, 0.8316831683168316)}
# Epoch 3 dev score:
# {'macro_f1': 0.3633350776207919, 'f1': (0.0, 0.44897959183673464, 0.6410256410256411), 'precision': (0.0, 0.5, 0.5952380952380952), 'recall': (0.0, 0.4074074074074074, 0.6944444444444444)}
# Epoch 4, iter 379, loss: 0.4074: 100%|██████████| 380/380 [02:01<00:00,  3.12it/s]
# Epoch 4 train score:
# {'macro_f1': 0.5955432039042626, 'f1': (0.5, 0.5125628140703518, 0.7740667976424361), 'precision': (0.9285714285714286, 0.864406779661017, 0.6416938110749185), 'recall': (0.34210526315789475, 0.36428571428571427, 0.9752475247524752)}
# Epoch 4 dev score:
# {'macro_f1': 0.32480620155038764, 'f1': (0.0, 0.3, 0.6744186046511629), 'precision': (0.0, 0.46153846153846156, 0.58), 'recall': (0.0, 0.2222222222222222, 0.8055555555555556)}

# %%
# Saved models, in /content/saved_models directory.
# !ls saved_models/
# Out:
# support_classifier-epoch-0-f1-1915  support_classifier-epoch-3-f1-3633
# support_classifier-epoch-1-f1-3324  support_classifier-epoch-4-f1-3248
# support_classifier-epoch-2-f1-2377

# %%
# Stance Prediction Module Design:
# Two stance prediction models will be required.
# Results are not looking promising for the 'NO' and 'NEUTRAL' classes
# As distinction between these two classes will be very hard.
# A separate stance prediction model might be required.
